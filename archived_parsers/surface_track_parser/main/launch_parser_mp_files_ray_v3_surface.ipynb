# %% [markdown]
# * Notes
#     * Filename: launch_parser_mp_files.ipynb
#     * Multiprocessing performed for each directory
#     * Example: For all files in each directory all surfaces for every file are executed in parallel
#     * High Memory Consumption IF imaris files are large

# %%
import sys

sys.path.append(".")

import os
import gc
import ray
import glob
import time
import numpy as np
from utils import utils
import concurrent.futures
from tqdm.notebook import tqdm

# %% [markdown]
# Get Available Categories

# %%
def generate_available_categories(config_path: str, save_path: str):
    # load config path
    yaml = utils.load_yaml(config_path)

    # type of parser
    parser_type = yaml["parser_type"]

    # extract category func
    extract_categories = utils.get_category_function(parser_type)

    # files to scan
    directories = yaml["data_dir"]

    # valid surface
    valid_surface = int(yaml["valid_surface"][0]) - 1

    for directory in directories:
        # grab all the files in the directory w/ .ims
        filenames = list(glob.glob(os.path.join(directory, "*.ims")))

        for filename in filenames:
            # file path
            file_path = filename

            # get and save the available categories csv file
            extract_categories(file_path, valid_surface, save_path)

            break

        break

    print("[info] Please Edit The Statistics File")

# %%
# RUN GENERATE CATEGORIES
# generate_available_categories("configs/config.yaml", ".")

# %% [markdown]
# Generate Statistics

# %%
def generate_statistics(config_path: str):
    # init ray
    ray.init(
        ignore_reinit_error=True,
    )
    
    chunk_size = 4

    # load config path
    yaml = utils.load_yaml(config_path)

    # type of parser
    parser_type = yaml["parser_type"]

    if parser_type == "track":
        from parsers.track_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    elif parser_type == "surface":
        from parsers.surface_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    elif parser_type == "first":
        from parsers.first_surface_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    else:
        raise ValueError("Invalid Parser Type")

    # files to scan
    directories = yaml["data_dir"]

    # get the stats categories
    stats_categories = utils.read_txt(yaml["stats_category_path"])

    # valid surface
    valid_surfaces = yaml["valid_surface"]

    # iterate, process and save
    # parallel processes all files within 1 directory at at time
    skip_list = []
    for idx, directory in tqdm(enumerate(directories)):
        print(f"[info] -- processing directory index: {idx+1}/{len(directories)}")

        # save dir
        save_dir = yaml["save_dir"][idx]

        # grab all the files in the directory w/ .ims
        filenames = list(glob.glob(os.path.join(directory, "*.ims")))
        
        filenames = np.array(filenames, dtype=str)
        num_chunks = np.ceil(len(filenames) / chunk_size)
        file_chunks = np.array_split(filenames, num_chunks)

        # create a list to hold ray subprocess
        
        for filenames in file_chunks:
            processes = []
            
            for filename in filenames.tolist():

                try:

                    print(f"\n[info] -- processing file {os.path.basename(filename)}\n")

                    # load the imaris file
                    data = utils.load_ims(filename)

                    for surface in valid_surfaces:
                        # create folder
                        folder_path = os.path.join(save_dir, str(surface))
                        if not os.path.isdir(folder_path):
                            os.makedirs(folder_path)

                        # convert to zero indexed surface value
                        current_surface = int(surface) - 1

                        # save_file_path
                        save_path = utils.get_save_filepath(
                            parser_type, folder_path, filename, (current_surface + 1)
                        )

                        # extract data
                        extracted_data = extract_data(
                            filename, data, current_surface, save_path
                        )

                        # process and save
                        if extracted_data:
                            # append stats categories to extracted data
                            extracted_data.update({"categories_list": stats_categories})
                            task_ref = process_and_save.remote(extracted_data)
                            processes.append(task_ref)

                        else:
                            # there is no surface deleting folder
                            if not os.listdir(folder_path):
                                    os.rmdir(folder_path)

                except Exception as e:
                        # for any reason it cannot execute a file it will skip that file
                        print(f"\t[info] -- error file: {filename}")
                        print(f"\t[info] -- raised Exception [{e}]")
                        print(f"\t[info] -- skipping file\n")
                        skip_list.append(filename)
                        pass        



            print("\n\t[info] -- finished data extraction")
            print(f"\t[info] -- found {len(processes)} surfaces")
            print(f"\t[info] -- processing {len(processes)} surfaces\n")

            ray.wait(processes, num_returns=len(processes))

            # memory clean up
            del data
            del processes
            gc.collect()
                


    np.savetxt("skipped_files.txt", np.array(skip_list, dtype=str), fmt="%s")

    ray.shutdown()
    print(f"\n[info] -- DONE")

# %%
# RUN GENERATE STATISTICS
start = time.perf_counter()
generate_statistics(config_path="configs/config_surface.yaml")
stop = time.perf_counter()
print(f"Total Run Time: {stop - start}")
# Out:
# 2023-08-21 11:34:00,160	INFO worker.py:1621 -- Started a local Ray instance.
# [info] -- parser mode: track
# 0it [00:00, ?it/s]
# [info] -- processing directory index: 1/4
#
# [info] -- processing file ALN Sec1 Roi1 2x2 1h30min.ims
#
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min.ims -- surface: 0
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 0
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min.ims -- surface: 2
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min.ims -- surface: 3
# (process_and_save pid=36328) 	[info] finished: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 2 -- processed 126 items
# (process_and_save pid=36328) 	[info] working on file: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 2 [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min.ims -- surface: 4
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 0 -- processed 2109 items [repeated 2x across cluster]
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min.ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN Sec1 Roi1 2x2 1h30min_1.ims
#
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min_1.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min_1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min_1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min_1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min_1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min_1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min_1.ims -- surface: 3
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2x2 1h30min.ims -- surface 3 -- processed 10635 items
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min_1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec1 Roi1 2x2 1h30min_1.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Roi1 2x2 1h30min_1.ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN Sec1 Tiled 16x12.ims
#
# 	[info] -- error file: \\niaid-fas1\Bioimaging\Users\rogandc\06162023 SIV infected VLP 6-color\ALN Sec1 Tiled 16x12.ims
# 	[info] -- raised Exception [[Errno 13] Unable to open file (file read failed: time = Mon Aug 21 11:36:00 2023
# , filename = '\\niaid-fas1\Bioimaging\Users\rogandc\06162023 SIV infected VLP 6-color\ALN Sec1 Tiled 16x12.ims', file descriptor = 6, errno = 13, error message = 'Permission denied', buf = 0000008ADC7E81F0, total read size = 8, bytes this sub-read = 8, bytes actually read = 18446744073709551615, offset = 0)]
# 	[info] -- skipping file
#
#
# [info] -- processing file ALN Sec2 Roi1 2x2 1h20min.ims
#
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- tracks not found in surface: 4
#
# 	[info] -- finished data extraction
# 	[info] -- found 4 surfaces
# 	[info] -- processing 4 surfaces
#
#
# [info] -- processing file ALN Sec2 Roi2 2x2 1h20min.ims
#
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h20min.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h20min.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h20min.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h20min.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h20min.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h20min.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h20min.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h20min.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h20min.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h20min.ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN Sec2 Tiled 13x17.ims
#
# 	[info] extracting data: ALN Sec2 Tiled 13x17.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Tiled 13x17.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec2 Tiled 13x17.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Tiled 13x17.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec2 Tiled 13x17.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Tiled 13x17.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec2 Tiled 13x17.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Tiled 13x17.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec2 Tiled 13x17.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec2 Tiled 13x17.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN Roi1 2x2 1h20min.ims
#
# 	[info] extracting data: ILN Roi1 2x2 1h20min.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Roi1 2x2 1h20min.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN Roi1 2x2 1h20min.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Roi1 2x2 1h20min.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN Roi1 2x2 1h20min.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Roi1 2x2 1h20min.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN Roi1 2x2 1h20min.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Roi1 2x2 1h20min.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN Roi1 2x2 1h20min.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Roi1 2x2 1h20min.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN Tiled 12x16.ims
#
# 	[info] extracting data: ILN Tiled 12x16.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 12x16.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN Tiled 12x16.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 12x16.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN Tiled 12x16.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 12x16.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN Tiled 12x16.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 12x16.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN Tiled 12x16.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 12x16.ims -- tracks not found in surface: 4
#
# 	[info] -- finished data extraction
# 	[info] -- found 0 surfaces
# 	[info] -- processing 0 surfaces
#
#
# [info] -- processing file ILN with VLP Roi1 2x2 1h20min.ims
#
# 	[info] extracting data: ILN with VLP Roi1 2x2 1h20min.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi1 2x2 1h20min.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Roi1 2x2 1h20min.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi1 2x2 1h20min.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Roi1 2x2 1h20min.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi1 2x2 1h20min.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Roi1 2x2 1h20min.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi1 2x2 1h20min.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Roi1 2x2 1h20min.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi1 2x2 1h20min.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN with VLP Roi2 2x2 1h.ims
#
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi2 2x2 1h.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi2 2x2 1h.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi2 2x2 1h.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi2 2x2 1h.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi2 2x2 1h.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN with VLP Roi3 2x2 1h.ims
#
# 	[info] extracting data: ILN with VLP Roi3 2x2 1h.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi3 2x2 1h.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Roi3 2x2 1h.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi3 2x2 1h.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Roi3 2x2 1h.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi3 2x2 1h.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Roi3 2x2 1h.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi3 2x2 1h.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Roi3 2x2 1h.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Roi3 2x2 1h.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN with VLP Tiled 12x18 incomplete.ims
#
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Tiled 12x18 incomplete.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Tiled 12x18 incomplete.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Tiled 12x18 incomplete.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Tiled 12x18 incomplete.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Tiled 12x18 incomplete.ims -- tracks not found in surface: 4
#
# 	[info] -- finished data extraction
# 	[info] -- found 0 surfaces
# 	[info] -- processing 0 surfaces
#
# [info] -- processing directory index: 2/4
#
# [info] -- processing file ALN Sec1 Roi1 2h.ims
#
# 	[info] extracting data: ALN Sec1 Roi1 2h.ims -- surface: 0
# 	[info] extracting data: ALN Sec1 Roi1 2h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2h.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2h.ims -- surface 0 -- processed 2116 items
# 	[info] extracting data: ALN Sec1 Roi1 2h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2h.ims -- surface 1
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2h.ims -- surface 1 -- processed 1259 items
# 	[info] extracting data: ALN Sec1 Roi1 2h.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2h.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2h.ims -- surface 2 -- processed 791 items
# 	[info] extracting data: ALN Sec1 Roi1 2h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec1 Roi1 2h.ims -- surface 4 not found
#
# [info] -- processing file ALN Sec1 Tiled 5x4.ims
#
# (process_and_save pid=21012) 	[info] working on file: ALN Sec1 Roi1 2h.ims -- surface 3
# 	[info] extracting data: ALN Sec1 Tiled 5x4.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x4.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec1 Tiled 5x4.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x4.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec1 Tiled 5x4.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x4.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec1 Tiled 5x4.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x4.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec1 Tiled 5x4.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec1 Tiled 5x4.ims -- surface 4 not found
#
# [info] -- processing file ALN Sec1 Tiled 5x5 repeat.ims
#
# 	[info] extracting data: ALN Sec1 Tiled 5x5 repeat.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x5 repeat.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Sec1 Tiled 5x5 repeat.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x5 repeat.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Sec1 Tiled 5x5 repeat.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x5 repeat.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Sec1 Tiled 5x5 repeat.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Sec1 Tiled 5x5 repeat.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Sec1 Tiled 5x5 repeat.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec1 Tiled 5x5 repeat.ims -- surface 4 not found
#
# [info] -- processing file ALN Sec2 Roi1 2x2 1h.ims
#
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h.ims -- surface: 0
# (process_and_save pid=21012) 	[info] finished: ALN Sec1 Roi1 2h.ims -- surface 3 -- processed 2109 items
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ALN Sec2 Roi1 2x2 1h.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: ALN Sec2 Roi1 2x2 1h.ims -- surface 0 -- processed 630 items
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ALN Sec2 Roi1 2x2 1h.ims -- surface 1
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: ALN Sec2 Roi1 2x2 1h.ims -- surface 2 -- processed 230 items
# (process_and_save pid=12764) 	[info] working on file: ALN Sec2 Roi1 2x2 1h.ims -- surface 2
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 8 surfaces
# 	[info] -- processing 8 surfaces
#
# (process_and_save pid=12764) 	[info] working on file: ALN Sec2 Roi1 2x2 1h.ims -- surface 3
#
# [info] -- processing file ALN Sec2 Roi2 2x2 1h30min.ims
#
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h30min.ims -- surface: 0
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h30min.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 0
# (process_and_save pid=12764) 	[info] finished: ALN Sec2 Roi1 2x2 1h.ims -- surface 3 -- processed 1055 items [repeated 2x across cluster]
# (process_and_save pid=12764) 	[info] finished: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 0 -- processed 1317 items
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h30min.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 1
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h30min.ims -- surface: 3
# (process_and_save pid=21012) 	[info] finished: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 2 -- processed 197 items
# 	[info] extracting data: ALN Sec2 Roi2 2x2 1h30min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi2 2x2 1h30min.ims -- surface 4 not found
#
# [info] -- processing file ILN Roi1 1h.ims
#
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 0
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ILN Roi1 1h.ims -- surface 0
# (process_and_save pid=21012) 	[info] working on file: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 3 [repeated 2x across cluster]
# (process_and_save pid=12764) 	[info] finished: ILN Roi1 1h.ims -- surface 0 -- processed 498 items
# (process_and_save pid=21012) 	[info] finished: ALN Sec2 Roi2 2x2 1h30min.ims -- surface 3 -- processed 1609 items [repeated 2x across cluster]
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN Roi1 1h.ims -- surface 1
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 3
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN Roi1 1h.ims -- surface 4 not found
#
# [info] -- processing file ILN Tiled 5x5.ims
#
# 	[info] extracting data: ILN Tiled 5x5.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 5x5.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN Tiled 5x5.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 5x5.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN Tiled 5x5.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 5x5.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN Tiled 5x5.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Tiled 5x5.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN Tiled 5x5.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN Tiled 5x5.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 8 surfaces
# 	[info] -- processing 8 surfaces
#
# (process_and_save pid=12764) 	[info] finished: ILN Roi1 1h.ims -- surface 1 -- processed 2972 items [repeated 3x across cluster]
#
# [info] -- processing file ILN with VLP Sec1 2x2 2h.ims
#
# 	[info] extracting data: ILN with VLP Sec1 2x2 2h.ims -- surface: 0
# 	[info] extracting data: ILN with VLP Sec1 2x2 2h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 2x2 2h.ims -- surface 0
# (process_and_save pid=21012) 	[info] working on file: ILN Roi1 1h.ims -- surface 3 [repeated 2x across cluster]
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 2x2 2h.ims -- surface 0 -- processed 636 items
# 	[info] extracting data: ILN with VLP Sec1 2x2 2h.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 2x2 2h.ims -- surface 1
# 	[info] extracting data: ILN with VLP Sec1 2x2 2h.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 2x2 2h.ims -- surface 2
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 2x2 2h.ims -- surface 1 -- processed 1412 items [repeated 2x across cluster]
# 	[info] extracting data: ILN with VLP Sec1 2x2 2h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec1 2x2 2h.ims -- surface 4 not found
#
# [info] -- processing file ILN with VLP Sec1 Roi1 1h.ims
#
# 	[info] extracting data: ILN with VLP Sec1 Roi1 1h.ims -- surface: 0
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 2x2 2h.ims -- surface 3
# 	[info] extracting data: ILN with VLP Sec1 Roi1 1h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi1 1h.ims -- surface 0 -- processed 1408 items
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi1 1h.ims -- surface 0
# 	[info] extracting data: ILN with VLP Sec1 Roi1 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi1 1h.ims -- surface 1
# 	[info] extracting data: ILN with VLP Sec1 Roi1 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 2x2 2h.ims -- surface 3 -- processed 11049 items
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 Roi1 1h.ims -- surface 2 -- processed 470 items
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 Roi1 1h.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi1 1h.ims -- surface 1 -- processed 2634 items
# 	[info] extracting data: ILN with VLP Sec1 Roi1 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec1 Roi1 1h.ims -- surface 4 not found
#
# [info] -- processing file ILN with VLP Sec1 Roi2 1h.ims
#
# 	[info] extracting data: ILN with VLP Sec1 Roi2 1h.ims -- surface: 0
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi1 1h.ims -- surface 3
# 	[info] extracting data: ILN with VLP Sec1 Roi2 1h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 Roi2 1h.ims -- surface 0 -- processed 1444 items
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 Roi2 1h.ims -- surface 0
# 	[info] extracting data: ILN with VLP Sec1 Roi2 1h.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 Roi2 1h.ims -- surface 1
# 	[info] extracting data: ILN with VLP Sec1 Roi2 1h.ims -- surface: 3
# (process_and_save pid=36328) 	[info] finished: ILN with VLP Sec1 Roi2 1h.ims -- surface 2 -- processed 191 items
# (process_and_save pid=36328) 	[info] working on file: ILN with VLP Sec1 Roi2 1h.ims -- surface 2
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Sec1 Roi2 1h.ims -- surface 1 -- processed 1782 items
# 	[info] extracting data: ILN with VLP Sec1 Roi2 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec1 Roi2 1h.ims -- surface 4 not found
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi2 1h.ims -- surface 3
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi1 1h.ims -- surface 3 -- processed 9904 items
#
# 	[info] -- finished data extraction
# 	[info] -- found 12 surfaces
# 	[info] -- processing 12 surfaces
#
#
# [info] -- processing file ILN with VLP Sec1 Roi3 1h.ims
#
# 	[info] extracting data: ILN with VLP Sec1 Roi3 1h.ims -- surface: 0
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi2 1h.ims -- surface 3 -- processed 5705 items
# 	[info] extracting data: ILN with VLP Sec1 Roi3 1h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi3 1h.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi3 1h.ims -- surface 0 -- processed 3025 items
# 	[info] extracting data: ILN with VLP Sec1 Roi3 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi3 1h.ims -- surface 1
# 	[info] extracting data: ILN with VLP Sec1 Roi3 1h.ims -- surface: 3
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi3 1h.ims -- surface 1 -- processed 3416 items [repeated 2x across cluster]
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Sec1 Roi3 1h.ims -- surface 2
# 	[info] extracting data: ILN with VLP Sec1 Roi3 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec1 Roi3 1h.ims -- surface 4 not found
#
# [info] -- processing file ILN with VLP Sec1 Tiled 4x7.ims
#
# 	[info] extracting data: ILN with VLP Sec1 Tiled 4x7.ims -- surface: 0
# (process_and_save pid=21012) 	[info] working on file: ILN with VLP Sec1 Roi3 1h.ims -- surface 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec1 Tiled 4x7.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Sec1 Tiled 4x7.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec1 Tiled 4x7.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Sec1 Tiled 4x7.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec1 Tiled 4x7.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Sec1 Tiled 4x7.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec1 Tiled 4x7.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Sec1 Tiled 4x7.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec1 Tiled 4x7.ims -- surface 4 not found
#
# [info] -- processing file ILN with VLP Sec2 Tiled 55x5.ims
#
# 	[info] extracting data: ILN with VLP Sec2 Tiled 55x5.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec2 Tiled 55x5.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN with VLP Sec2 Tiled 55x5.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec2 Tiled 55x5.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN with VLP Sec2 Tiled 55x5.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec2 Tiled 55x5.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN with VLP Sec2 Tiled 55x5.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN with VLP Sec2 Tiled 55x5.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN with VLP Sec2 Tiled 55x5.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN with VLP Sec2 Tiled 55x5.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 4 surfaces
# 	[info] -- processing 4 surfaces
#
# (process_and_save pid=21012) 	[info] finished: ILN with VLP Sec1 Roi3 1h.ims -- surface 3 -- processed 13367 items
# [info] -- processing directory index: 3/4
#
# [info] -- processing file 2ALN Roi1 1h20min.ims
#
# 	[info] extracting data: 2ALN Roi1 1h20min.ims -- surface: 0
# 	[info] extracting data: 2ALN Roi1 1h20min.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: 2ALN Roi1 1h20min.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: 2ALN Roi1 1h20min.ims -- surface 0 -- processed 367 items
# 	[info] extracting data: 2ALN Roi1 1h20min.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: 2ALN Roi1 1h20min.ims -- surface 1
# (process_and_save pid=21012) 	[info] finished: 2ALN Roi1 1h20min.ims -- surface 1 -- processed 536 items
# 	[info] extracting data: 2ALN Roi1 1h20min.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: 2ALN Roi1 1h20min.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: 2ALN Roi1 1h20min.ims -- surface 2 -- processed 496 items
# 	[info] extracting data: 2ALN Roi1 1h20min.ims -- surface: 4
# (process_and_save pid=21012) 	[info] working on file: 2ALN Roi1 1h20min.ims -- surface 3
# (process_and_save pid=21012) 	[info] finished: 2ALN Roi1 1h20min.ims -- surface 3 -- processed 1362 items
#
# [info] -- processing file 2ILN Roi1 1h.ims
#
# 	[info] extracting data: 2ILN Roi1 1h.ims -- surface: 0
# (process_and_save pid=21012) 	[info] working on file: 2ALN Roi1 1h20min.ims -- surface 4
# 	[info] extracting data: 2ILN Roi1 1h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] finished: 2ILN Roi1 1h.ims -- surface 0 -- processed 222 items
# 	[info] extracting data: 2ILN Roi1 1h.ims -- surface: 2
# 	[info] extracting data: 2ILN Roi1 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: 2ILN Roi1 1h.ims -- surface 1 -- processed 848 items
# 	[info] extracting data: 2ILN Roi1 1h.ims -- surface: 4
# (process_and_save pid=12764) 	[info] working on file: 2ILN Roi1 1h.ims -- surface 3 [repeated 4x across cluster]
# (process_and_save pid=12764) 	[info] finished: 2ILN Roi1 1h.ims -- surface 3 -- processed 1697 items [repeated 2x across cluster]
# (process_and_save pid=21012) 	[info] finished: 2ALN Roi1 1h20min.ims -- surface 4 -- processed 104415 items
#
# [info] -- processing file ALN Half-sec 1.ims
#
# 	[info] extracting data: ALN Half-sec 1.ims -- surface: 0
# (process_and_save pid=21012) 	[info] working on file: 2ILN Roi1 1h.ims -- surface 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Half-sec 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Half-sec 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Half-sec 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Half-sec 1.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec 1.ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims
#
# 	[info] extracting data: ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Bottom half_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 4
#
# 	[info] -- finished data extraction
# 	[info] -- found 10 surfaces
# 	[info] -- processing 10 surfaces
#
# (process_and_save pid=21012) 	[info] finished: 2ILN Roi1 1h.ims -- surface 4 -- processed 129446 items
#
# [info] -- processing file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims
#
# 	[info] extracting data: ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Half-sec Tiled Top_[ims1_2023-06-20T17-56-13.890].ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN NS half-sec NS.ims
#
# 	[info] extracting data: ALN NS half-sec NS.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN NS half-sec NS.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN NS half-sec NS.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN NS half-sec NS.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN NS half-sec NS.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN NS half-sec NS.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN NS half-sec NS.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN NS half-sec NS.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN NS half-sec NS.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN NS half-sec NS.ims -- tracks not found in surface: 4
#
# [info] -- processing file ALN Roi1 1h.ims
#
# 	[info] extracting data: ALN Roi1 1h.ims -- surface: 0
# 	[info] extracting data: ALN Roi1 1h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ALN Roi1 1h.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: ALN Roi1 1h.ims -- surface 0 -- processed 189 items
# 	[info] extracting data: ALN Roi1 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ALN Roi1 1h.ims -- surface 1
# (process_and_save pid=21012) 	[info] finished: ALN Roi1 1h.ims -- surface 1 -- processed 534 items
# 	[info] extracting data: ALN Roi1 1h.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: ALN Roi1 1h.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: ALN Roi1 1h.ims -- surface 2 -- processed 683 items
# 	[info] extracting data: ALN Roi1 1h.ims -- surface: 4
# (process_and_save pid=21012) 	[info] working on file: ALN Roi1 1h.ims -- surface 3
# (process_and_save pid=21012) 	[info] finished: ALN Roi1 1h.ims -- surface 3 -- processed 1288 items
#
# [info] -- processing file ALN Tiled middle.ims
#
# 	[info] extracting data: ALN Tiled middle.ims -- surface: 0
# (process_and_save pid=21012) 	[info] working on file: ALN Roi1 1h.ims -- surface 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled middle.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Tiled middle.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled middle.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Tiled middle.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled middle.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Tiled middle.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled middle.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Tiled middle.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled middle.ims -- tracks not found in surface: 4
#
# 	[info] -- finished data extraction
# 	[info] -- found 5 surfaces
# 	[info] -- processing 5 surfaces
#
# (process_and_save pid=21012) 	[info] finished: ALN Roi1 1h.ims -- surface 4 -- processed 114520 items
#
# [info] -- processing file ALN Tiled top.ims
#
# 	[info] extracting data: ALN Tiled top.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled top.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN Tiled top.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled top.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN Tiled top.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled top.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN Tiled top.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled top.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN Tiled top.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN Tiled top.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN 2x2 Argon laser fails.ims
#
# 	[info] extracting data: ILN 2x2 Argon laser fails.ims -- surface: 0
# 	[info] extracting data: ILN 2x2 Argon laser fails.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ILN 2x2 Argon laser fails.ims -- surface 0
# 	[info] extracting data: ILN 2x2 Argon laser fails.ims -- surface: 2
# 	[info] extracting data: ILN 2x2 Argon laser fails.ims -- surface: 3
# 	[info] extracting data: ILN 2x2 Argon laser fails.ims -- surface: 4
# (process_and_save pid=32772) 	[info] finished: ILN 2x2 Argon laser fails.ims -- surface 3 -- processed 205 items
# (process_and_save pid=32772) 	[info] working on file: ILN 2x2 Argon laser fails.ims -- surface 3 [repeated 3x across cluster]
#
# [info] -- processing file ILN Roi1 1h.ims
#
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 0
# (process_and_save pid=36328) 	[info] finished: ILN 2x2 Argon laser fails.ims -- surface 2 -- processed 1582 items [repeated 3x across cluster]
# (process_and_save pid=36328) 	[info] working on file: ILN 2x2 Argon laser fails.ims -- surface 4
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 1
# (process_and_save pid=21012) 	[info] working on file: ILN Roi1 1h.ims -- surface 0
# (process_and_save pid=21012) 	[info] finished: ILN Roi1 1h.ims -- surface 0 -- processed 127 items
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ILN Roi1 1h.ims -- surface 1
# (process_and_save pid=21012) 	[info] finished: ILN Roi1 1h.ims -- surface 1 -- processed 930 items
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: ILN Roi1 1h.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: ILN Roi1 1h.ims -- surface 2 -- processed 702 items
# 	[info] extracting data: ILN Roi1 1h.ims -- surface: 4
# (process_and_save pid=21012) 	[info] working on file: ILN Roi1 1h.ims -- surface 3
# (process_and_save pid=21012) 	[info] finished: ILN Roi1 1h.ims -- surface 3 -- processed 3942 items
# (process_and_save pid=36328) 	[info] finished: ILN 2x2 Argon laser fails.ims -- surface 4 -- processed 96790 items
#
# [info] -- processing file ILN Roi2 2x2 1h.ims
#
# 	[info] extracting data: ILN Roi2 2x2 1h.ims -- surface: 0
# (process_and_save pid=36328) 	[info] working on file: ILN Roi1 1h.ims -- surface 4
# 	[info] extracting data: ILN Roi2 2x2 1h.ims -- surface: 1
# 	[info] extracting data: ILN Roi2 2x2 1h.ims -- surface: 2
# (process_and_save pid=21012) 	[info] finished: ILN Roi2 2x2 1h.ims -- surface 0 -- processed 1794 items
# (process_and_save pid=21012) 	[info] working on file: ILN Roi2 2x2 1h.ims -- surface 0
# (process_and_save pid=12764) 	[info] working on file: ILN Roi2 2x2 1h.ims -- surface 1
# 	[info] extracting data: ILN Roi2 2x2 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] working on file: ILN Roi2 2x2 1h.ims -- surface 2
# 	[info] extracting data: ILN Roi2 2x2 1h.ims -- surface: 4
# (process_and_save pid=12764) 	[info] working on file: ILN Roi2 2x2 1h.ims -- surface 3
# (process_and_save pid=12764) 	[info] finished: ILN Roi2 2x2 1h.ims -- surface 2 -- processed 1546 items [repeated 2x across cluster]
#
# 	[info] -- finished data extraction
# 	[info] -- found 15 surfaces
# 	[info] -- processing 15 surfaces
#
# (process_and_save pid=21012) 	[info] working on file: ILN Roi2 2x2 1h.ims -- surface 4
# (process_and_save pid=36328) 	[info] finished: ILN Roi1 1h.ims -- surface 4 -- processed 77972 items [repeated 3x across cluster]
#
# [info] -- processing file ILN Roi2 2x2 30min.ims
#
# 	[info] extracting data: ILN Roi2 2x2 30min.ims -- surface: 0
# 	[info] extracting data: ILN Roi2 2x2 30min.ims -- surface: 1
# (process_and_save pid=36328) 	[info] working on file: ILN Roi2 2x2 30min.ims -- surface 0
# 	[info] extracting data: ILN Roi2 2x2 30min.ims -- surface: 2
# (process_and_save pid=36328) 	[info] finished: ILN Roi2 2x2 30min.ims -- surface 0 -- processed 4189 items
# (process_and_save pid=12764) 	[info] working on file: ILN Roi2 2x2 30min.ims -- surface 1
# 	[info] extracting data: ILN Roi2 2x2 30min.ims -- surface: 3
# (process_and_save pid=36328) 	[info] working on file: ILN Roi2 2x2 30min.ims -- surface 2
# (process_and_save pid=36328) 	[info] finished: ILN Roi2 2x2 30min.ims -- surface 2 -- processed 653 items
# 	[info] extracting data: ILN Roi2 2x2 30min.ims -- surface: 4
#
# [info] -- processing file ILN Whole tiled 1.ims
#
# 	[info] extracting data: ILN Whole tiled 1.ims -- surface: 0
# (process_and_save pid=12764) 	[info] finished: ILN Roi2 2x2 30min.ims -- surface 1 -- processed 2712 items
# (process_and_save pid=36328) 	[info] working on file: ILN Roi2 2x2 30min.ims -- surface 4 [repeated 2x across cluster]
# (process_and_save pid=36328) 	[info] finished: ILN Roi2 2x2 30min.ims -- surface 4 -- processed 2430 items
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN Whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN Whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN Whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN Whole tiled 1.ims -- surface: 4
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN Whole tiled 1.ims -- tracks not found in surface: 4
#
# [info] -- processing file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims
#
# 	[info] extracting data: ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- surface: 0
# 		[info] -- raised no surface exception
# 		[info] -- skipping file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- no surfaces found
# 	[info] extracting data: ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- surface: 1
# 		[info] -- raised no surface exception
# 		[info] -- skipping file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- no surfaces found
# 	[info] extracting data: ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- surface: 2
# 		[info] -- raised no surface exception
# 		[info] -- skipping file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- no surfaces found
# 	[info] extracting data: ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- surface: 3
# 		[info] -- raised no surface exception
# 		[info] -- skipping file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- no surfaces found
# 	[info] extracting data: ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- surface: 4
# 		[info] -- raised no surface exception
# 		[info] -- skipping file ILN with VLP Half-sec tiled 1_[ii116_TileScan_4_(Stage_117_of_117)_Image_117].ims -- no surfaces found
#
# [info] -- processing file ILN with VLP Roi1 2x2 30min.ims
#
# 	[info] extracting data: ILN with VLP Roi1 2x2 30min.ims -- surface: 0
# 	[info] extracting data: ILN with VLP Roi1 2x2 30min.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi1 2x2 30min.ims -- surface 0
# (process_and_save pid=12764) 	[info] finished: ILN Roi2 2x2 30min.ims -- surface 3 -- processed 3576 items
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Roi1 2x2 30min.ims -- surface 0 -- processed 314 items
# 	[info] extracting data: ILN with VLP Roi1 2x2 30min.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi1 2x2 30min.ims -- surface 1
# 	[info] extracting data: ILN with VLP Roi1 2x2 30min.ims -- surface: 3
# 	[info] extracting data: ILN with VLP Roi1 2x2 30min.ims -- surface: 4
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi1 2x2 30min.ims -- surface 3 [repeated 2x across cluster]
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Roi1 2x2 30min.ims -- surface 3 -- processed 2380 items [repeated 3x across cluster]
#
# 	[info] -- finished data extraction
# 	[info] -- found 10 surfaces
# 	[info] -- processing 10 surfaces
#
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi1 2x2 30min.ims -- surface 4
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Roi1 2x2 30min.ims -- surface 4 -- processed 32741 items
#
# [info] -- processing file ILN with VLP Roi2 2x2 1h.ims
#
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 0
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi2 2x2 1h.ims -- surface 0
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Roi2 2x2 1h.ims -- surface 0 -- processed 320 items
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi2 2x2 1h.ims -- surface 1
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: ILN with VLP Roi2 2x2 1h.ims -- surface 1 -- processed 1610 items [repeated 2x across cluster]
# 	[info] extracting data: ILN with VLP Roi2 2x2 1h.ims -- surface: 4
# (process_and_save pid=12764) 	[info] working on file: ILN with VLP Roi2 2x2 1h.ims -- surface 3 [repeated 2x across cluster]
# ...
# 	[info] extracting data: ALN NS whole tiled 2.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN NS whole tiled 2.ims -- surface 4 not found
#
# [info] -- processing file ALN P2 2x2 Roi1 1h.ims
#
# 	[info] extracting data: ALN P2 2x2 Roi1 1h.ims -- surface: 0
# 	[info] extracting data: ALN P2 2x2 Roi1 1h.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ALN P2 2x2 Roi1 1h.ims -- surface 0
# 	[info] extracting data: ALN P2 2x2 Roi1 1h.ims -- surface: 2
# (process_and_save pid=36328) 	[info] finished: ALN P2 2x2 Roi1 1h.ims -- surface 1 -- processed 395 items
# (process_and_save pid=36328) 	[info] working on file: ALN P2 2x2 Roi1 1h.ims -- surface 1
# 	[info] extracting data: ALN P2 2x2 Roi1 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] working on file: ALN P2 2x2 Roi1 1h.ims -- surface 2
# (process_and_save pid=12764) 	[info] finished: ALN P2 2x2 Roi1 1h.ims -- surface 0 -- processed 2270 items
# (process_and_save pid=12764) 	[info] finished: ALN P2 2x2 Roi1 1h.ims -- surface 2 -- processed 5559 items
# 	[info] extracting data: ALN P2 2x2 Roi1 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN P2 2x2 Roi1 1h.ims -- surface 4 not found
#
# [info] -- processing file ALN P3 2x2 Roi1 1h20min.ims
#
# 	[info] extracting data: ALN P3 2x2 Roi1 1h20min.ims -- surface: 0
# (process_and_save pid=12764) 	[info] working on file: ALN P2 2x2 Roi1 1h.ims -- surface 3
# 	[info] extracting data: ALN P3 2x2 Roi1 1h20min.ims -- surface: 1
# (process_and_save pid=36328) 	[info] working on file: ALN P3 2x2 Roi1 1h20min.ims -- surface 0
# 	[info] extracting data: ALN P3 2x2 Roi1 1h20min.ims -- surface: 2
# (process_and_save pid=21012) 	[info] working on file: ALN P3 2x2 Roi1 1h20min.ims -- surface 1
# (process_and_save pid=21012) 	[info] finished: ALN P3 2x2 Roi1 1h20min.ims -- surface 1 -- processed 66 items
# 	[info] extracting data: ALN P3 2x2 Roi1 1h20min.ims -- surface: 3
# (process_and_save pid=21012) 	[info] working on file: ALN P3 2x2 Roi1 1h20min.ims -- surface 2
# (process_and_save pid=21012) 	[info] finished: ALN P3 2x2 Roi1 1h20min.ims -- surface 2 -- processed 68 items
# (process_and_save pid=36328) 	[info] finished: ALN P3 2x2 Roi1 1h20min.ims -- surface 0 -- processed 2432 items
# (process_and_save pid=12764) 	[info] finished: ALN P2 2x2 Roi1 1h.ims -- surface 3 -- processed 9677 items
# 	[info] extracting data: ALN P3 2x2 Roi1 1h20min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN P3 2x2 Roi1 1h20min.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 8 surfaces
# 	[info] -- processing 8 surfaces
#
# (process_and_save pid=12764) 	[info] working on file: ALN P3 2x2 Roi1 1h20min.ims -- surface 3
# (process_and_save pid=12764) 	[info] finished: ALN P3 2x2 Roi1 1h20min.ims -- surface 3 -- processed 8255 items
#
# [info] -- processing file ALN P3 whole tiled 1.ims
#
# 	[info] extracting data: ALN P3 whole tiled 1.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN P3 whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ALN P3 whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN P3 whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ALN P3 whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN P3 whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ALN P3 whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ALN P3 whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ALN P3 whole tiled 1.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN P3 whole tiled 1.ims -- surface 4 not found
#
# [info] -- processing file ILN P1 whole tiled 1.ims
#
# 	[info] extracting data: ILN P1 whole tiled 1.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P1 whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P1 whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P1 whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P1 whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P1 whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P1 whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P1 whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P1 whole tiled 1.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P1 whole tiled 1.ims -- surface 4 not found
#
# [info] -- processing file ILN P2 2x2 1h30min.ims
#
# 	[info] extracting data: ILN P2 2x2 1h30min.ims -- surface: 0
# 	[info] extracting data: ILN P2 2x2 1h30min.ims -- surface: 1
# (process_and_save pid=12764) 	[info] working on file: ILN P2 2x2 1h30min.ims -- surface 0
# (process_and_save pid=12764) 	[info] finished: ILN P2 2x2 1h30min.ims -- surface 0 -- processed 2085 items
# 	[info] extracting data: ILN P2 2x2 1h30min.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN P2 2x2 1h30min.ims -- surface 1
# (process_and_save pid=12764) 	[info] finished: ILN P2 2x2 1h30min.ims -- surface 1 -- processed 2263 items
# 	[info] extracting data: ILN P2 2x2 1h30min.ims -- surface: 3
# (process_and_save pid=12764) 	[info] working on file: ILN P2 2x2 1h30min.ims -- surface 2
# (process_and_save pid=12764) 	[info] finished: ILN P2 2x2 1h30min.ims -- surface 2 -- processed 1098 items
# 	[info] extracting data: ILN P2 2x2 1h30min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P2 2x2 1h30min.ims -- surface 4 not found
#
# [info] -- processing file ILN P2 2x2 Roi2 1h.ims
#
# 	[info] extracting data: ILN P2 2x2 Roi2 1h.ims -- surface: 0
# (process_and_save pid=12764) 	[info] working on file: ILN P2 2x2 1h30min.ims -- surface 3
# 	[info] extracting data: ILN P2 2x2 Roi2 1h.ims -- surface: 1
# (process_and_save pid=36328) 	[info] working on file: ILN P2 2x2 Roi2 1h.ims -- surface 0
# (process_and_save pid=36328) 	[info] finished: ILN P2 2x2 Roi2 1h.ims -- surface 0 -- processed 4522 items
# 	[info] extracting data: ILN P2 2x2 Roi2 1h.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN P2 2x2 Roi2 1h.ims -- surface 1
# 	[info] extracting data: ILN P2 2x2 Roi2 1h.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: ILN P2 2x2 1h30min.ims -- surface 3 -- processed 12856 items
# (process_and_save pid=12764) 	[info] finished: ILN P2 2x2 Roi2 1h.ims -- surface 1 -- processed 4500 items
# (process_and_save pid=36328) 	[info] working on file: ILN P2 2x2 Roi2 1h.ims -- surface 2
# 	[info] extracting data: ILN P2 2x2 Roi2 1h.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P2 2x2 Roi2 1h.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 8 surfaces
# 	[info] -- processing 8 surfaces
#
# (process_and_save pid=36328) 	[info] working on file: ILN P2 2x2 Roi2 1h.ims -- surface 3
# (process_and_save pid=36328) 	[info] finished: ILN P2 2x2 Roi2 1h.ims -- surface 2 -- processed 1841 items
# (process_and_save pid=36328) 	[info] finished: ILN P2 2x2 Roi2 1h.ims -- surface 3 -- processed 15565 items
#
# [info] -- processing file ILN P2 whole tiled 1.ims
#
# 	[info] extracting data: ILN P2 whole tiled 1.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P2 whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P2 whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P2 whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P2 whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P2 whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P2 whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P2 whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P2 whole tiled 1.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P2 whole tiled 1.ims -- surface 4 not found
#
# [info] -- processing file ILN P3 2x2 Roi1 1h30min.ims
#
# 	[info] extracting data: ILN P3 2x2 Roi1 1h30min.ims -- surface: 0
# 	[info] extracting data: ILN P3 2x2 Roi1 1h30min.ims -- surface: 1
# (process_and_save pid=36328) 	[info] working on file: ILN P3 2x2 Roi1 1h30min.ims -- surface 0
# (process_and_save pid=36328) 	[info] finished: ILN P3 2x2 Roi1 1h30min.ims -- surface 0 -- processed 2268 items
# 	[info] extracting data: ILN P3 2x2 Roi1 1h30min.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 2x2 Roi1 1h30min.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P3 2x2 Roi1 1h30min.ims -- surface: 3
# (process_and_save pid=36328) 	[info] working on file: ILN P3 2x2 Roi1 1h30min.ims -- surface 1
# (process_and_save pid=36328) 	[info] finished: ILN P3 2x2 Roi1 1h30min.ims -- surface 1 -- processed 2297 items
# 	[info] extracting data: ILN P3 2x2 Roi1 1h30min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 2x2 Roi1 1h30min.ims -- surface 4 not found
#
# [info] -- processing file ILN P3 2x2 Roi1 30min.ims
#
# 	[info] extracting data: ILN P3 2x2 Roi1 30min.ims -- surface: 0
# (process_and_save pid=36328) 	[info] working on file: ILN P3 2x2 Roi1 1h30min.ims -- surface 3
# 	[info] extracting data: ILN P3 2x2 Roi1 30min.ims -- surface: 1
# (process_and_save pid=12764) 	[info] finished: ILN P3 2x2 Roi1 30min.ims -- surface 0 -- processed 1951 items
# (process_and_save pid=12764) 	[info] working on file: ILN P3 2x2 Roi1 30min.ims -- surface 0
# 	[info] extracting data: ILN P3 2x2 Roi1 30min.ims -- surface: 2
# (process_and_save pid=12764) 	[info] working on file: ILN P3 2x2 Roi1 30min.ims -- surface 1
# 	[info] extracting data: ILN P3 2x2 Roi1 30min.ims -- surface: 3
# (process_and_save pid=12764) 	[info] finished: ILN P3 2x2 Roi1 30min.ims -- surface 1 -- processed 2148 items [repeated 2x across cluster]
# (process_and_save pid=21012) 	[info] working on file: ILN P3 2x2 Roi1 30min.ims -- surface 2
# 	[info] extracting data: ILN P3 2x2 Roi1 30min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 2x2 Roi1 30min.ims -- surface 4 not found
#
# [info] -- processing file ILN P3 whole tiled 1.ims
#
# 	[info] extracting data: ILN P3 whole tiled 1.ims -- surface: 0
# (process_and_save pid=36328) 	[info] working on file: ILN P3 2x2 Roi1 30min.ims -- surface 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P3 whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P3 whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P3 whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P3 whole tiled 1.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 whole tiled 1.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 7 surfaces
# 	[info] -- processing 7 surfaces
#
#
# [info] -- processing file ILN P3 whole tiled 2 repeat 2.ims
#
# 	[info] extracting data: ILN P3 whole tiled 2 repeat 2.ims -- surface: 0
# (process_and_save pid=36328) 	[info] finished: ILN P3 2x2 Roi1 30min.ims -- surface 3 -- processed 5707 items [repeated 2x across cluster]
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat 2.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P3 whole tiled 2 repeat 2.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat 2.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P3 whole tiled 2 repeat 2.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat 2.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P3 whole tiled 2 repeat 2.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat 2.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P3 whole tiled 2 repeat 2.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat 2.ims -- surface 4 not found
#
# [info] -- processing file ILN P3 whole tiled 2 repeat.ims
#
# 	[info] extracting data: ILN P3 whole tiled 2 repeat.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P3 whole tiled 2 repeat.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P3 whole tiled 2 repeat.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P3 whole tiled 2 repeat.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P3 whole tiled 2 repeat.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 whole tiled 2 repeat.ims -- surface 4 not found
#
# [info] -- processing file ILN P3 whole tiled 2.ims
#
# 	[info] extracting data: ILN P3 whole tiled 2.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN P3 whole tiled 2.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN P3 whole tiled 2.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN P3 whole tiled 2.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN P3 whole tiled 2.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN P3 whole tiled 2.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN P3 whole tiled 2.ims -- surface 4 not found
#
# [info] -- processing file ILN whole tiled 1.ims
#
# 	[info] extracting data: ILN whole tiled 1.ims -- surface: 0
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN whole tiled 1.ims -- tracks not found in surface: 0
# 	[info] extracting data: ILN whole tiled 1.ims -- surface: 1
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN whole tiled 1.ims -- tracks not found in surface: 1
# 	[info] extracting data: ILN whole tiled 1.ims -- surface: 2
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN whole tiled 1.ims -- tracks not found in surface: 2
# 	[info] extracting data: ILN whole tiled 1.ims -- surface: 3
# 		[info] -- raised no track exception
# 		[info] -- skipping file ILN whole tiled 1.ims -- tracks not found in surface: 3
# 	[info] extracting data: ILN whole tiled 1.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ILN whole tiled 1.ims -- surface 4 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 0 surfaces
# 	[info] -- processing 0 surfaces
#
#
# [info] -- DONE
# Total Run Time: 3635.9073209

# %%
# Working

# %%
import numpy as np

# %%
l = ['one', 'two'] * 4
print(l)
# Out:
# ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']

# %%
np.array_split(np.array(l, dtype=str), 2)[0].tolist()
# Out:
# ['one', 'two', 'one', 'two']

# %%
np.ceil(len(l) / 5)
# Out:
# 2.0
