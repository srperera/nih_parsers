# %%
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
from parsers.filament_parser import FilamentParserDistributed
from parsers_v2.filament_parser import (
    FilamentParserDistributed as FilamentParserDistributed_v2,
)

# %%
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/filaments/NeuronDemo_with_objects.ims"
parser = FilamentParserDistributed(ims_file_path=ims_file)
parser_v2 = FilamentParserDistributed_v2(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
start = time.perf_counter()
out = parser.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 12.632980807917193

# %%
start = time.perf_counter()
out_v2 = parser_v2.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 1.5117485909722745

# %%
final = out["final_df"]
final_v2 = out_v2["final_df"]
print(final.equals(final_v2))
print(final_v2.equals(final))
# Out:
# True
# True
