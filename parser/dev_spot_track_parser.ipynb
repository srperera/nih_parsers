# %%
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject

# from parsers.spot import SpotParserDistributed
from parsers_v2.spot_track_parser import (
    SpotTrackParserDistributed as SpotTrackParserDistributed_v2,
)

# %%
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/spots/Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10].ims"
# parser = SpotParserDistributed(ims_file_path=ims_file)
parser_v2 = SpotTrackParserDistributed_v2(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
# start = time.perf_counter()
# out = parser.inspect(0)
# stop = time.perf_counter()
# print(f"run time: {stop - start}")

# %%
parser_v2.track_ids[2]

# %%
start = time.perf_counter()
out_v2 = parser_v2.inspect(2)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 start = time.perf_counter()
# ----> 2 out_v2 = parser_v2.inspect(2)
#       3 stop = time.perf_counter()
#       4 print(f"run time: {stop - start}")
#
# File ~/Documents/projects/nih/nih_parsers/parser/parsers_v2/spot_track_parser.py:273, in SpotTrackParserDistributed.inspect(self, spot_id)
#     270 storage["stat_names_channel_info"] = stat_names
#     272 # filter stats values by object ids (ie: ignore info related to trackids)
# --> 273 stat_values = self._filter_stats(
#     274     stats_values=stat_values,
#     275     filter_col_names=["ID_Object"],
#     276     filter_values=[track_id],
#     277 )
#     278 storage["stat_values_filtered"] = stat_values
#     280 # organize stats value
#
# File ~/Documents/projects/nih/nih_parsers/parser/parsers_v2/parser_base.py:71, in Parser._filter_stats(self, stats_values, filter_col_names, filter_values)
#      69 # first filter stats values by object id
#      70 for col_names, values in zip(filter_col_names, filter_values):
# ---> 71     stats_values = stats_values[stats_values[col_names].isin(values)]
#      73 return stats_values
#
# File ~/anaconda3/envs/core/lib/python3.12/site-packages/pandas/core/series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# File ~/anaconda3/envs/core/lib/python3.12/site-packages/pandas/core/algorithms.py:477, in isin(comps, values)
#     472     raise TypeError(
#     473         "only list-like objects are allowed to be passed "
#     474         f"to isin(), you passed a `{type(comps).__name__}`"
#     475     )
#     476 if not is_list_like(values):
# --> 477     raise TypeError(
#     478         "only list-like objects are allowed to be passed "
#     479         f"to isin(), you passed a `{type(values).__name__}`"
#     480     )
#     482 if not isinstance(values, (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray)):
#     483     orig_values = list(values)
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a `NoneType`

# %%
# final = out["final_df"]
final_v2 = out_v2["final_df"]
# print(final.equals(final_v2))
# print(final_v2.equals(final))

# %%
final_v2
# Out:
#             Track Ar1 Mean  Track Ar1 X  Track Ar1 Y  Track Ar1 Z  \
# 1000001241       -0.548451    -0.432649    -0.632247    -0.580456
# 1000001818       -0.410397    -0.484583    -0.437152    -0.309458
# 1000001927       -0.146257     0.080063     0.356383    -0.875216
# 1000001973       -0.447120    -0.570450    -0.491917    -0.278994
# 1000002021       -0.234696     0.065542    -0.360542    -0.409089
# ...                    ...          ...          ...          ...
# 1004945574             NaN          NaN          NaN          NaN
# 1004945595             NaN          NaN          NaN          NaN
# 1004945636             NaN          NaN          NaN          NaN
# 1004945736             NaN          NaN          NaN          NaN
# 1004945765             NaN          NaN          NaN          NaN
#
#             Track Area Mean  Track Diameter Mean  Track Displacement Length  \
# 1000001241       270.691437             9.333332                   1.117910
# 1000001818       270.691467             9.333333                   9.426201
# 1000001927       270.691437             9.333333                  17.968460
# 1000001973       270.691437             9.333334                   3.819228
# 1000002021       270.691437             9.333332                   2.112756
# ...                     ...                  ...                        ...
# 1004945574       270.691467             9.333333                   9.194887
# 1004945595       270.691467             9.333333                   2.166599
# 1004945636       270.691467             9.333333                   2.172507
# 1004945736       270.691467             9.333333                  10.533698
# 1004945765       270.691467             9.333333                   2.018071
#
#             Track Displacement X  Track Displacement Y  Track Displacement Z  \
# 1000001241             -0.398956             -0.970734             -0.385010
# 1000001818              6.356750              6.918732             -0.759033
# 1000001927              5.555298            -17.085327             -0.309570
# 1000001973              0.071533             -3.759247              0.670410
# 1000002021              1.632385              1.249969              0.486450
# ...                          ...                   ...                   ...
# 1004945574             -8.492981             -2.582642              2.396912
# 1004945595             -0.447144             -2.072632              0.445435
# 1004945636              0.732483             -1.942505             -0.640259
# 1004945736              9.650391              4.222412              0.000000
# 1004945765             -1.509766             -1.339111              0.000000
#
#             ...  Track Position Z Mean  Track Position Z Start  \
# 1000001241  ...             520.638428              520.673401
# 1000001818  ...             512.581421              513.130493
# 1000001927  ...             521.747131              521.857117
# 1000001973  ...             521.448608              521.200684
# 1000002021  ...             521.833008              520.979309
# ...         ...                    ...                     ...
# 1004945574  ...             531.863403              530.664978
# 1004945595  ...             531.377869              531.155151
# 1004945636  ...             533.277710              533.597839
# 1004945736  ...             543.014343              543.014343
# 1004945765  ...             543.014343              543.014343
#
#             Track Speed Max  Track Speed Mean  Track Speed Min  \
# 1000001241         1.973185          0.863472         0.330802
# 1000001818         3.541132          2.440099         0.871268
# 1000001927         5.686681          3.003753         0.530947
# 1000001973        10.239689          2.321373         0.553788
# 1000002021         6.290761          1.290185         0.269516
# ...                     ...               ...              ...
# 1004945574         9.194887          9.194887         9.194887
# 1004945595         2.166599          2.166599         2.166599
# 1004945636         2.172507          2.172507         2.172507
# 1004945736        10.533698         10.533698        10.533698
# 1004945765         2.018071          2.018071         2.018071
#
#             Track Speed StdDev  Track Speed Variation  Track Straightness  \
# 1000001241            0.442049               0.511944            0.019039
# 1000001818            0.612988               0.251214            0.772608
# 1000001927            1.783228               0.593666            0.854572
# 1000001973            2.394171               1.031360            0.049856
# 1000002021            1.141237               0.884553            0.024082
# ...                        ...                    ...                 ...
# 1004945574            0.000000               0.000000            1.000000
# 1004945595            0.000000               0.000000            1.000000
# 1004945636            0.000000               0.000000            1.000000
# 1004945736            0.000000               0.000000            1.000000
# 1004945765            0.000000               0.000000            1.000000
#
#             Track Volume Mean    Track_ID
# 1000001241         402.123596  1000001241
# 1000001818         402.123871  1000001818
# 1000001927         402.123840  1000001927
# 1000001973         402.123962  1000001973
# 1000002021         402.123596  1000002021
# ...                       ...         ...
# 1004945574         402.123871  1004945574
# 1004945595         402.123871  1004945595
# 1004945636         402.123871  1004945636
# 1004945736         402.123871  1004945736
# 1004945765         402.123871  1004945765
#
# [16675 rows x 58 columns]

# %%
out_v2["factor"]
