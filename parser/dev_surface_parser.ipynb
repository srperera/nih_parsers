# %%
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
from parsers.surface_parser import SurfaceParserDistributed
from parsers_v2.surface_parser import (
    SurfaceParserDistributed as SurfaceParserDistributed_v2,
)

# %%
# ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/surface/P2 rectum merged restained_1_[ims1_2025-08-18T14-27-29.640].ims"
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/tracks/GFP #1 Sec2 Roi1 2x2 1h30min.ims"
parser = SurfaceParserDistributed(ims_file_path=ims_file)
parser_v2 = SurfaceParserDistributed_v2(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
start = time.perf_counter()
out = parser.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 54.799930716864765

# %%
start = time.perf_counter()
out_v2 = parser_v2.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 9.611787370871753

# %%
final = out["final_df"]
final_v2 = out_v2["final_df"]
print(final.equals(final_v2))
print(final_v2.equals(final))
# Out:
# False
# False

# %%
ims.contains_tracks("MegaSurfaces0")
# Out:
# True

# %%
for i in list(final.columns):
    if i not in list(final_v2.columns):
        print(i)
# Out:
# Center_of_Image_Mass_X Channel_1
# Center_of_Image_Mass_X Channel_2
# Center_of_Image_Mass_X Channel_3
# Center_of_Image_Mass_X Channel_4
# Center_of_Image_Mass_X Channel_5
# Center_of_Image_Mass_Y Channel_1
# Center_of_Image_Mass_Y Channel_2
# Center_of_Image_Mass_Y Channel_3
# Center_of_Image_Mass_Y Channel_4
# Center_of_Image_Mass_Y Channel_5
# Center_of_Image_Mass_Z Channel_1
# Center_of_Image_Mass_Z Channel_2
# Center_of_Image_Mass_Z Channel_3
# Center_of_Image_Mass_Z Channel_4
# Center_of_Image_Mass_Z Channel_5
# Intensity_Center Channel_1
# Intensity_Center Channel_2
# Intensity_Center Channel_3
# Intensity_Center Channel_4
# Intensity_Center Channel_5
# Intensity_Max Channel_1
# Intensity_Max Channel_2
# Intensity_Max Channel_3
# Intensity_Max Channel_4
# Intensity_Max Channel_5
# Intensity_Mean Channel_1
# Intensity_Mean Channel_2
# Intensity_Mean Channel_3
# Intensity_Mean Channel_4
# Intensity_Mean Channel_5
# Intensity_Median Channel_1
# Intensity_Median Channel_2
# Intensity_Median Channel_3
# Intensity_Median Channel_4
# Intensity_Median Channel_5
# Intensity_Min Channel_1
# Intensity_Min Channel_2
# Intensity_Min Channel_3
# Intensity_Min Channel_4
# Intensity_Min Channel_5
# Intensity_StdDev Channel_1
# Intensity_StdDev Channel_2
# Intensity_StdDev Channel_3
# Intensity_StdDev Channel_4
# Intensity_StdDev Channel_5
# Intensity_Sum Channel_1
# Intensity_Sum Channel_2
# Intensity_Sum Channel_3
# Intensity_Sum Channel_4
# Intensity_Sum Channel_5
# Intensity_Sum_of_Square Channel_1
# Intensity_Sum_of_Square Channel_2
# Intensity_Sum_of_Square Channel_3
# Intensity_Sum_of_Square Channel_4
# Intensity_Sum_of_Square Channel_5
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_Ratio_to_Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped_Volume_to_Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest_Distance_to_Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]

# %%
for i in list(final_v2.columns):
    if i not in list(final.columns):
        print(i)
# Out:
# Center of Image Mass X Channel_1
# Center of Image Mass X Channel_2
# Center of Image Mass X Channel_3
# Center of Image Mass X Channel_4
# Center of Image Mass X Channel_5
# Center of Image Mass Y Channel_1
# Center of Image Mass Y Channel_2
# Center of Image Mass Y Channel_3
# Center of Image Mass Y Channel_4
# Center of Image Mass Y Channel_5
# Center of Image Mass Z Channel_1
# Center of Image Mass Z Channel_2
# Center of Image Mass Z Channel_3
# Center of Image Mass Z Channel_4
# Center of Image Mass Z Channel_5
# Intensity Center Channel_1
# Intensity Center Channel_2
# Intensity Center Channel_3
# Intensity Center Channel_4
# Intensity Center Channel_5
# Intensity Max Channel_1
# Intensity Max Channel_2
# Intensity Max Channel_3
# Intensity Max Channel_4
# Intensity Max Channel_5
# Intensity Mean Channel_1
# Intensity Mean Channel_2
# Intensity Mean Channel_3
# Intensity Mean Channel_4
# Intensity Mean Channel_5
# Intensity Median Channel_1
# Intensity Median Channel_2
# Intensity Median Channel_3
# Intensity Median Channel_4
# Intensity Median Channel_5
# Intensity Min Channel_1
# Intensity Min Channel_2
# Intensity Min Channel_3
# Intensity Min Channel_4
# Intensity Min Channel_5
# Intensity StdDev Channel_1
# Intensity StdDev Channel_2
# Intensity StdDev Channel_3
# Intensity StdDev Channel_4
# Intensity StdDev Channel_5
# Intensity Sum Channel_1
# Intensity Sum Channel_2
# Intensity Sum Channel_3
# Intensity Sum Channel_4
# Intensity Sum Channel_5
# Intensity Sum of Square Channel_1
# Intensity Sum of Square Channel_2
# Intensity Sum of Square Channel_3
# Intensity Sum of Square Channel_4
# Intensity Sum of Square Channel_5
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume Ratio to Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume to Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume to Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume to Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Overlapped Volume to Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume to Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume to Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Overlapped Volume to Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest Distance to Surfaces_Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest Distance to Surfaces_Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest Distance to Surfaces_Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]
# Shortest Distance to Surfaces_Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest Distance to Surfaces_Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest Distance to Surfaces_Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
# Shortest Distance to Surfaces_Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]
