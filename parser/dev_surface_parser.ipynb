# %%
import os
import ray
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
from parsers.surface_parser import SurfaceParserDistributed
import time

# %%
#ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/surface/P2 rectum merged restained_1_[ims1_2025-08-18T14-27-29.640].ims"
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/tracks/GFP #1 Sec2 Roi1 2x2 1h30min.ims"
ims = ImarisDataObject(ims_file)
data = ims.data
parser = SurfaceParserDistributed(ims_file_path=ims_file)
# Out:
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE

# %%
out = parser.inspect(0)

# %%
f = out["final_df"]
f2 = out["final_df2"]
f.equals(f2)
# Out:
# True

# %%
ims.get_object_names("Surface")
# Out:
# ['MegaSurfaces0',
#  'MegaSurfaces1',
#  'MegaSurfaces2',
#  'MegaSurfaces3',
#  'MegaSurfaces4',
#  'MegaSurfaces5',
#  'MegaSurfaces6',
#  'MegaSurfaces7']

# %%
ims.get_object_ids("MegaSurfaces0")
# Out:
# HERE
# 0              1
# 1              3
# 2              5
# 3              6
# 4              8
#            ...
# 101183    224428
# 101184    224510
# 101185    224560
# 101186    224617
# 101187    224722
# Length: 101188, dtype: int64

# %%
ims.get_track_ids("MegaSurfaces0")
# Out:
# 0       1000000000
# 1       1000000001
# 2       1000000003
# 3       1000000005
# 4       1000000006
#            ...
# 2778    1000222046
# 2779    1000222137
# 2780    1000222184
# 2781    1000222245
# 2782    1000222357
# Name: ID, Length: 2783, dtype: int64

# %%
ims.get_stats_values("MegaSurfaces0")
# Out:
#           ID_Time  ID_Object  ID_StatisticsType         Value
# 0              -1         -1                  5  2.783000e+03
# 1              -1         -1                  6  1.011890e+05
# 2              -1         -1                  7  1.011890e+05
# 3              -1         -1                  8  8.234778e+07
# 4              -1         -1                  9  2.437183e+07
# ...           ...        ...                ...           ...
# 13951570       79     224428              26291  2.075231e+02
# 13951571       79     224510              26291  6.038209e+02
# 13951572       79     224560              26291  3.067408e+02
# 13951573       79     224617              26291  1.227466e+03
# 13951574       79     224722              26291  5.689697e+02
#
# [13951575 rows x 4 columns]

# %%
track_ids = ims.get_track_ids("MegaSurfaces0")

# filter stats values to remove track ids
stats_values = stats_values[~stats_values["ID_Object"].isin(track_ids)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 track_ids = ims.get_track_ids("MegaSurfaces0")
#       3 # filter stats values to remove track ids
# ----> 4 stats_values = stats_values[~stats_values["ID_Object"].isin(track_ids)]
#
# File ~/anaconda3/envs/core/lib/python3.12/site-packages/pandas/core/series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# File ~/anaconda3/envs/core/lib/python3.12/site-packages/pandas/core/algorithms.py:477, in isin(comps, values)
# ...

# %%
track_ids
