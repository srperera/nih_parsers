# %%
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
from parsers.track_parser import TrackParserDistributed
from parsers_v2.track_parser import TrackParserDistributed as TrackParserDistributed_v2

# %%
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/tracks/GFP #1 Sec2 Roi1 2x2 1h30min.ims"
parser = TrackParserDistributed(ims_file_path=ims_file)
parser_v2 = TrackParserDistributed_v2(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
start = time.perf_counter()
out = parser.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 6.987337992992252

# %%
start = time.perf_counter()
out_v2 = parser_v2.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 0.47300911508500576

# %%
final = out["final_df"]
final_v2 = out_v2["final_df"]
print(final.equals(final_v2))
print(final_v2.equals(final))
# Out:
# True
# True
