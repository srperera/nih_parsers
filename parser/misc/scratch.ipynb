# %%
import os
import yaml
import numpy as np
from imaris.imaris import ImarisDataObject
from typing import List
import pandas as pd
import time
from tqdm.notebook import tqdm

# %%
data_path = "/home/shehan/Documents/projects/nih_parsers/data/filaments/NeuronDemo_with_objects.ims"
os.path.isfile(data_path)
# Out:
# True

# %%
parser = ImarisDataObject(data_path)
data = parser.data

# %%
data.get("Scene8").get("Content").keys()
# Out:
# <KeysViewHDF5 ['Filaments0', 'Filaments1', 'Points0']>
