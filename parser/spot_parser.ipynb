# %%
import os
import ray
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from scripts_v2.process_spots import (
    run_spot_track_object_parser_parallel,
    run_spot_track_parser_parallel,
)

# %%
config_path = "config/config_spots.yaml"
config = load_yaml(config_path)

# %%
# initiliaze ray
ray.init(num_cpus=int(config["cpu_cores"]), ignore_reinit_error=True)

if not isinstance(config["valid_spots"], list):
    print(f"[info] -- running all available surfaces")

    if int(config["valid_spots"]) == -1:
        run_spot_track_object_parser_parallel(
            data_dirs=config["data_dir"],
            save_dirs=config["save_dir"],
            cpu_cores=config["cpu_cores"],
            spot_ids=None,
        )


elif isinstance(config["valid_surfaces"], list):
    print(f"[info] -- running specified surfaces")

    valid_spots = [int(x) for x in config["valid_spots"]]

    run_spot_track_object_parser_parallel(
        data_dirs=config["data_dir"],
        save_dirs=config["save_dir"],
        cpu_cores=config["cpu_cores"],
        spot_ids=valid_spots,
    )
else:
    raise NotImplementedError
# Out:
# 2025-08-21 15:33:19,437	INFO worker.py:1786 -- Started a local Ray instance.
# [info] -- running all available surfaces
# ['/home/shehan/Documents/projects/nih/nih_parsers/data/spots/Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10].ims']
# [info] -- points id: 0 -- points: Points0 -- Valid
# [info] -- points id: 1 -- points: Points1 -- Valid
# [info] -- points id: 2 -- points: Points2 -- Valid
# [info] -- points id: 3 -- points: Points3 -- Valid
# [info] -- points id: 4 -- points: Points4 -- Valid
# [info] -- creating 5 actors for Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]
#
#
# [info] -- found 5 actors
# [info] -- extracting data ...
# (SpotTrackObjectParserDistributed pid=2680180) [info] -- finished: Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]_spot_track_objects_3.csv
# (SpotTrackObjectParserDistributed pid=2680178) [info] -- finished: Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]_spot_track_objects_4.csv [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (SpotTrackObjectParserDistributed pid=2680179) [info] -- finished: Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]_spot_track_objects_2.csv
# [info] -- complete.
# (SpotTrackObjectParserDistributed pid=2680181) [info] -- finished: Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]_spot_track_objects_1.csv
# (SpotTrackParserDistributed pid=2680918) [info] -- finished: Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]_spot_track_1.csv

# %%
if not isinstance(config["valid_spots"], list):
    print(f"[info] -- running all available surfaces")

    if int(config["valid_spots"]) == -1:
        run_spot_track_parser_parallel(
            data_dirs=config["data_dir"],
            save_dirs=config["save_dir"],
            cpu_cores=config["cpu_cores"],
            spot_ids=None,
        )


elif isinstance(config["valid_surfaces"], list):
    print(f"[info] -- running specified surfaces")

    valid_spots = [int(x) for x in config["valid_spots"]]

    run_spot_track_parser_parallel(
        data_dirs=config["data_dir"],
        save_dirs=config["save_dir"],
        cpu_cores=config["cpu_cores"],
        spot_ids=valid_spots,
    )
else:
    raise NotImplementedError
# Out:
# [info] -- running all available surfaces
# ['/home/shehan/Documents/projects/nih/nih_parsers/data/spots/Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10].ims']
# [info] -- points id: 0 -- points: Points0 -- Valid
# [info] -- points id: 1 -- points: Points1 -- Valid
# [info] -- points id: 2 -- points: Points2 -- Invalid Skipping
# [info] -- points id: 3 -- points: Points3 -- Valid
# [info] -- points id: 4 -- points: Points4 -- Valid
# [info] -- creating 4 actors for Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10]
#
#
# [info] -- found 4 actors
# [info] -- extracting data ...
# [info] -- complete.
