# %%
import os
import ray
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from imaris.imaris import ImarisDataObject
from parsers.track_parser import TrackParserDistributed
from typing import List, Dict

# %%
data_path = (
    "../data/multi_surface_track_parser_dev_data/GFP #1 Sec1 Roi2 2x2 1h30min.ims"
)
os.path.isfile(data_path)
# Out:
# True

# %%
def get_ims_obj(data_path):
    ims_obj = ImarisDataObject(data_path)
    # assert ims_obj type


def get_final_df(data_path, init_surface_id=0):
    parser = TrackParserDistributed.remote(data_path, surface_id=init_surface_id)
    final_df = parser.inspect.remote(surface_id=0)
    final_df = ray.get(final_df)["stats_df"]
    # assert data type


def get_stats_dict_reversed(data_path, init_surface_id=0):
    parser = TrackParserDistributed.remote(data_path, surface_id=init_surface_id)
    stats_dict = parser.get_surface_stats_info.remote(surface_id=0)
    stats_dict = ray.get(stats_dict)
    stats_dict = {v: k for k, v in stats_dict.items()}
    # assert data type


def verify_stats(data_path, init_surface_id=0):
    parser = TrackParserDistributed.remote(data_path, surface_id=init_surface_id)
    # get generated df
    final_df = parser.inspect.remote(surface_id=0)
    final_df = ray.get(final_df)
    generated_df = final_df["stats_df"].T
    # get stats dict that maps ID to Name
    stats_dict = parser.get_surface_stats_info.remote(surface_id=0)
    stats_dict = ray.get(stats_dict)
    stats_dict = {v: k for k, v in stats_dict.items()}
    # get original data
    ims_obj = ImarisDataObject(data_path)
    raw_stats = ims_obj.get_stats_values(final_df["surface_name"])

# %%
parser1 = TrackParserDistributed.remote(data_path, surface_id=2)
parser2 = TrackParserDistributed.remote(data_path, surface_id=2)
# Out:
# 2023-11-27 23:39:35,849	INFO worker.py:1621 -- Started a local Ray instance.

# %%
# get generated df
final_df = parser1.inspect.remote(surface_id=0)
final_df = ray.get(final_df)
generated_df = final_df["stats_df"]

# get stats dict that maps ID to Name
stats_dict = parser2.get_surface_track_stats_info.remote(surface_id=0)
stats_dict = ray.get(stats_dict)

# get original data
ims_obj = ImarisDataObject(data_path)
raw_stats = ims_obj.get_stats_values(final_df["surface_name"])

# %%
def validate(
    gen_stats: pd.DataFrame,
    raw_obj_stats: pd.DataFrame,
    stats_dict: Dict,
) -> None:
    """
    Given a single row of statistics ie: all the stats for a single
    objectid and the raw stats values dictionary for the same object id
    this function will compare each statistics value between the generated
    version and the raw stats values dictionary obtained directly from the
    imaris file to ensure every stat values match for the given object id.

    Args:
        gen_stats (pd.DataFrame): dataframe for all the stats for a single object id
        raw_obj_stats (pd.DataFrame): raw stats values for a single object id
        stats_dict (Dict): dictionary that maps Stats ID Number to Stat Name

    Raises:
        ValueError: _description_
    """
    raw_obj_id = raw_obj_stats["ID_Object"].unique().item()
    gen_obj_id = gen_stats["Object_ID"].item()
    assert raw_obj_id == gen_obj_id, "Object IDs Do NOT Match"

    gen_values = {}
    # key = stats name, value=generated stats value for stats name
    for stats_name in gen_stats.columns.to_list():
        if "Track" in stats_name:
            gen_values[stats_name] = gen_stats[stats_name].item()
    if gen_values.get("Object_ID"):
        gen_values.pop("Object_ID")

    raw_values = {}
    for stat_id in raw_obj_stats["ID_StatisticsType"].to_list():
        stats_name = stats_dict[stat_id]
        if "Track" in stats_name:
            stats_value = raw_obj_stats[raw_obj_stats["ID_StatisticsType"] == stat_id]
            raw_values[stats_name] = stats_value["Value"].item()

    print(len(list(gen_values.keys())), len(list(raw_values.keys())))
    
    # double check all keys in both dicts are the same
    assert list(gen_values.keys()) == list(
        raw_values.keys()
    ), f"gen and raw does not match {raw_obj_id}"
    # if list(gen_values.keys()) != list(
    #     raw_values.keys()
    # ):
    #     print("HEREHRE")

    for key in gen_values.keys():
        raw_value = raw_values[key]
        gen_value = gen_values[key]
        if raw_value != gen_value:
            print(key, raw_value, gen_value)
            raise ValueError

    print(f"[info] -- confirmed all values for object {raw_obj_id}")

# %%
import concurrent.futures


def run_stats_validation(
    generated_df: pd.DataFrame,
    raw_stats: pd.DataFrame,
    stats_dict: Dict,
) -> None:
    """_summary_

    Args:
        generated_df (pd.DataFrame): _description_
        raw_stats (pd.DataFrame): _description_
        stats_dict (Dict): _description_
    """
    with concurrent.futures.ProcessPoolExecutor() as executor:
        executor_objects = [None] * len(generated_df["Object_ID"].to_list())
        for idx, object_id in tqdm(enumerate(generated_df["Object_ID"].to_list())):
            # get generated stats info for object id
            gen_stats = generated_df[generated_df["Object_ID"] == object_id]
            # get raw stats values for object id
            raw_obj_stats = raw_stats[raw_stats["ID_Object"] == object_id]

            executor_objects[idx] = executor.submit(
                validate, gen_stats, raw_obj_stats, stats_dict
            )
    for obj in executor_objects:
        obj.result()

# %%
run_stats_validation(generated_df, raw_stats, stats_dict[0])
# Out:
# 0it [00:00, ?it/s]
# 105 105
# 105[info] -- confirmed all values for object 1000000001
# 105
# [info] -- confirmed all values for object 1000000004
# 105 105
# [info] -- confirmed all values for object 1000000005
# 105 105
# [info] -- confirmed all values for object 1000000006
# 105 105
# [info] -- confirmed all values for object 1000000009
# 105 105105
# [info] -- confirmed all values for object 1000000010
# 105
# [info] -- confirmed all values for object 1000000011
# 105105  105105
# 105
# [info] -- confirmed all values for object 1000000013[info] -- confirmed all values for object 1000000007
#
# 105
# [info] -- confirmed all values for object 1000000012
# 105105  105105
#
# [info] -- confirmed all values for object 1000000014[info] -- confirmed all values for object 1000000008
#
# 105 105
# 105[info] -- confirmed all values for object 1000000017
#  105
# [info] -- confirmed all values for object 1000000016
# 105 105
# [info] -- confirmed all values for object 1000000018
# 105 105
# [info] -- confirmed all values for object 1000000019
# 105 105
# [info] -- confirmed all values for object 1000000021
# 105 105
# [info] -- confirmed all values for object 1000000022
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000024
# 105 105
# [info] -- confirmed all values for object 1000000025
# 105 105
# [info] -- confirmed all values for object 1000000027
# 105 105
# [info] -- confirmed all values for object 1000000026
# 105 105105
#  [info] -- confirmed all values for object 1000000029105
#
# [info] -- confirmed all values for object 1000000028
# 105 105
# [info] -- confirmed all values for object 1000000031
# 105105  105
#
# 101[info] -- confirmed all values for object 1000000032
# 105 105
# [info] -- confirmed all values for object 1000000033
# 105 105
# [info] -- confirmed all values for object 1000000035
# 105 105
# [info] -- confirmed all values for object 1000000039105
#  105
# 105[info] -- confirmed all values for object 1000000038
#  105
# [info] -- confirmed all values for object 1000000042
# 105 105
# [info] -- confirmed all values for object 1000000043
# 105 105
# [info] -- confirmed all values for object 1000000044
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000046
# 105 105105
#  [info] -- confirmed all values for object 1000000048105
#
# [info] -- confirmed all values for object 1000000047
# 105 105
# [info] -- confirmed all values for object 1000000049
# 105105 105
# [info] -- confirmed all values for object 1000000051
# 105
# [info] -- confirmed all values for object 1000000050
# 105105
# [info] -- confirmed all values for object 1000000052
# 105 105
# [info] -- confirmed all values for object 1000000054
#  105105
# [info] -- confirmed all values for object 1000000055
# 105
# 105[info] -- confirmed all values for object 1000000056
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000059
# 105 105
# [info] -- confirmed all values for object 1000000060
# 105 105
# 105[info] -- confirmed all values for object 1000000062
#  105
# [info] -- confirmed all values for object 1000000061
# 105105
# [info] -- confirmed all values for object 1000000063
# 105 105
# [info] -- confirmed all values for object 1000000064
# 105 105
# [info] -- confirmed all values for object 1000000067
# 105105
# [info] -- confirmed all values for object 1000000066
# 105 105
# [info] -- confirmed all values for object 1000000068105
#  105
# [info] -- confirmed all values for object 1000000069
# 105 105
# 105[info] -- confirmed all values for object 1000000071105
#  105105
# [info] -- confirmed all values for object 1000000072
#
# [info] -- confirmed all values for object 1000000073
# 105 105
# [info] -- confirmed all values for object 1000000074
# 105 105
#
# [info] -- confirmed all values for object 1000000075105 105
# [info] -- confirmed all values for object 1000000076
# 105 105105 105
#
# [info] -- confirmed all values for object 1000000078[info] -- confirmed all values for object 1000000077
#
# 105105  105105
#
# [info] -- confirmed all values for object 1000000080
# [info] -- confirmed all values for object 1000000079
# 105 105
# [info] -- confirmed all values for object 1000000081
# 105 105
# [info] -- confirmed all values for object 1000000082
# 105 105
# [info] -- confirmed all values for object 1000000083
# 105 105
# [info] -- confirmed all values for object 1000000085
# 105 105
# [info] -- confirmed all values for object 1000000084
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000087
# 105 105105
#  [info] -- confirmed all values for object 1000000089105
#
# [info] -- confirmed all values for object 1000000088
# 105 105
# [info] -- confirmed all values for object 1000000090
# 105 105
# [info] -- confirmed all values for object 1000000092
# 105 105
# [info] -- confirmed all values for object 1000000091
# 105105
# [info] -- confirmed all values for object 1000000094105
# 105
# 105[info] -- confirmed all values for object 1000000095
#
# 105[info] -- confirmed all values for object 1000000097
# 105 105
# [info] -- confirmed all values for object 1000000102105
#  105105
# 105[info] -- confirmed all values for object 1000000100
#
# [info] -- confirmed all values for object 1000000099
# 105 105
# [info] -- confirmed all values for object 1000000103
# 105 105
# [info] -- confirmed all values for object 1000000104
# 105 105
# [info] -- confirmed all values for object 1000000107
# 105 105
# [info] -- confirmed all values for object 1000000106
# 105105  105105
#
# [info] -- confirmed all values for object 1000000108[info] -- confirmed all values for object 1000000109
#
# 105 105105
#  105[info] -- confirmed all values for object 1000000112105
#
# 105[info] -- confirmed all values for object 1000000111
#
# [info] -- confirmed all values for object 1000000110
# 105 105
# [info] -- confirmed all values for object 1000000113105
# 105
# [info] -- confirmed all values for object 1000000114
# 105 105105 105
#
#
# [info] -- confirmed all values for object 1000000115[info] -- confirmed all values for object 1000000116
# 105 105
# [info] -- confirmed all values for object 1000000117
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000118
# 105 105
# [info] -- confirmed all values for object 1000000121
# 105 105
# [info] -- confirmed all values for object 1000000120
# 105 105
# [info] -- confirmed all values for object 1000000123
# 105 105101
# 105
# [info] -- confirmed all values for object 1000000126
# 105 105
# 105 [info] -- confirmed all values for object 1000000125105
#
# [info] -- confirmed all values for object 1000000127
# 105 105
# [info] -- confirmed all values for object 1000000128
# 105 105105
#  105[info] -- confirmed all values for object 1000000130
#
# [info] -- confirmed all values for object 1000000132
# 105 105
# [info] -- confirmed all values for object 1000000129
# 105 105
# [info] -- confirmed all values for object 1000000134
# 105 105
# [info] -- confirmed all values for object 1000000135
# 105105  105105
#
# [info] -- confirmed all values for object 1000000136[info] -- confirmed all values for object 1000000137
#
# 105 105
#
# [info] -- confirmed all values for object 1000000138105 105
# [info] -- confirmed all values for object 1000000139
# 105 105
# [info] -- confirmed all values for object 1000000141
# 105 105
# 105[info] -- confirmed all values for object 1000000140
# 105
# [info] -- confirmed all values for object 1000000142
# 105 105
# [info] -- confirmed all values for object 1000000144
# 105 105
# [info] -- confirmed all values for object 1000000145
# 105 105
# [info] -- confirmed all values for object 1000000147
# 105 105
# [info] -- confirmed all values for object 1000000146
# 105 105
# [info] -- confirmed all values for object 1000000149
# 105 105
# [info] -- confirmed all values for object 1000000148
# 105 105
# [info] -- confirmed all values for object 1000000150
# 105 105
# [info] -- confirmed all values for object 1000000151
# 105 105
# [info] -- confirmed all values for object 1000000153
# 105 105 105105
#
# [info] -- confirmed all values for object 1000000156[info] -- confirmed all values for object 1000000152
#
# 105 105
# [info] -- confirmed all values for object 1000000157105
#  105
# [info] -- confirmed all values for object 1000000154
# 105 105
# [info] -- confirmed all values for object 1000000160
# 105 105
# [info] -- confirmed all values for object 1000000159
# 105105  105105
#
# [info] -- confirmed all values for object 1000000162[info] -- confirmed all values for object 1000000161
#
# 105 105
# 105[info] -- confirmed all values for object 1000000164
# 105
# [info] -- confirmed all values for object 1000000163
# 105105 105
# 105101
#  [info] -- confirmed all values for object 1000000165105
#
# [info] -- confirmed all values for object 1000000166
# 105 105
# [info] -- confirmed all values for object 1000000168
# 105 105
# [info] -- confirmed all values for object 1000000169105
#  105
# [info] -- confirmed all values for object 1000000170
# 105105
# [info] -- confirmed all values for object 1000000171
# 105 105
# [info] -- confirmed all values for object 1000000172
# 105 105105 105
#
# [info] -- confirmed all values for object 1000000174[info] -- confirmed all values for object 1000000173
#
# 105 105
# [info] -- confirmed all values for object 1000000175
# 105 105
# [info] -- confirmed all values for object 1000000176
# 105 105
# [info] -- confirmed all values for object 1000000178
# 105 105
# [info] -- confirmed all values for object 1000000179
# 105 105[info] -- confirmed all values for object 1000000177
#
# 105 105105
# 105
# [info] -- confirmed all values for object 1000000182
# [info] -- confirmed all values for object 1000000180
# 105105  105105
# [info] -- confirmed all values for object 1000000181
#
# [info] -- confirmed all values for object 1000000185
# 105 105
# [info] -- confirmed all values for object 1000000184
# 105 105
# 105[info] -- confirmed all values for object 1000000186
#  105
# [info] -- confirmed all values for object 1000000188
# 105 105
# [info] -- confirmed all values for object 1000000187
# 105105  105105
#
# [info] -- confirmed all values for object 1000000189
# [info] -- confirmed all values for object 1000000191
# 105 105
# [info] -- confirmed all values for object 1000000190
# 105 105
#
# [info] -- confirmed all values for object 1000000192105105  105105
#
# [info] -- confirmed all values for object 1000000194
#
# [info] -- confirmed all values for object 1000000193105105  105105
# [info] -- confirmed all values for object 1000000196
#
# [info] -- confirmed all values for object 1000000195
# 105 105
# [info] -- confirmed all values for object 1000000197
# 105 105
# [info] -- confirmed all values for object 1000000198
# 105 105
# 105[info] -- confirmed all values for object 1000000200
#  105
# [info] -- confirmed all values for object 1000000199
# 105 105
# [info] -- confirmed all values for object 1000000202105
#  105
# [info] -- confirmed all values for object 1000000203
# 105 105
# [info] -- confirmed all values for object 1000000204
# 105 105
# [info] -- confirmed all values for object 1000000206
# 105 105
# [info] -- confirmed all values for object 1000000207
# 105105
# [info] -- confirmed all values for object 1000000208
# 105 105105
# 105[info] -- confirmed all values for object 1000000209
#
# [info] -- confirmed all values for object 1000000210
# 105105
# [info] -- confirmed all values for object 1000000212
# 105 105
# [info] -- confirmed all values for object 1000000211
# 105 105
# 105 [info] -- confirmed all values for object 1000000215105
#
# [info] -- confirmed all values for object 1000000213
# 105 105105
#  105105[info] -- confirmed all values for object 1000000217
#
# 105[info] -- confirmed all values for object 1000000216
#
# [info] -- confirmed all values for object 1000000218
# 105 105
# [info] -- confirmed all values for object 1000000219
# 105 105
# [info] -- confirmed all values for object 1000000220
# 105 105
# [info] -- confirmed all values for object 1000000221
# 105 105
# [info] -- confirmed all values for object 1000000222
# 105 105
# [info] -- confirmed all values for object 1000000223
# 105 105
# [info] -- confirmed all values for object 1000000224
# 105105  105101
#
# [info] -- confirmed all values for object 1000000225
# 105 105
# 105[info] -- confirmed all values for object 1000000228
# 105
# [info] -- confirmed all values for object 1000000227
# 105 105
# [info] -- confirmed all values for object 1000000230
# 105105
# [info] -- confirmed all values for object 1000000231
# 105 105
# [info] -- confirmed all values for object 1000000232
# 105 105
# [info] -- confirmed all values for object 1000000233
# 105 105
# [info] -- confirmed all values for object 1000000234
# 105105
# [info] -- confirmed all values for object 1000000236
# 105 105
# [info] -- confirmed all values for object 1000000237105
#  105
# [info] -- confirmed all values for object 1000000238
# 105 105
# [info] -- confirmed all values for object 1000000239
# 105 105
# [info] -- confirmed all values for object 1000000240
# 105 105
# [info] -- confirmed all values for object 1000000241
# 105 105105105
#  105[info] -- confirmed all values for object 1000000243105
#
#
# [info] -- confirmed all values for object 1000000242[info] -- confirmed all values for object 1000000244
#
# 105 105105
#  [info] -- confirmed all values for object 1000000246105
#
# [info] -- confirmed all values for object 1000000247
# 105 105
# [info] -- confirmed all values for object 1000000248
# 105 105105 105
#
# [info] -- confirmed all values for object 1000000249
# [info] -- confirmed all values for object 1000000250
# 105 105
# [info] -- confirmed all values for object 1000000251
# 105105  105105
#
# [info] -- confirmed all values for object 1000000254[info] -- confirmed all values for object 1000000253
#
# 105
# 105[info] -- confirmed all values for object 1000000252
# 105 105
# [info] -- confirmed all values for object 1000000256
# 105 105
# [info] -- confirmed all values for object 1000000255105
#  105
# 105[info] -- confirmed all values for object 1000000258
#
# 105[info] -- confirmed all values for object 1000000257
# 105 105
#
# [info] -- confirmed all values for object 1000000259105 105
# [info] -- confirmed all values for object 1000000260
# 105 105
# [info] -- confirmed all values for object 1000000263105
#  105
# [info] -- confirmed all values for object 1000000264
# 105 105
# [info] -- confirmed all values for object 1000000266
# 105 105105
#  105[info] -- confirmed all values for object 1000000268
# [info] -- confirmed all values for object 1000000267
#
# 105 105
# [info] -- confirmed all values for object 1000000271
# 105 105105
# 105[info] -- confirmed all values for object 1000000272
#
# [info] -- confirmed all values for object 1000000274
# 105105  105105
#
# [info] -- confirmed all values for object 1000000275
# [info] -- confirmed all values for object 1000000273
# 105 105105 105
#  105105[info] -- confirmed all values for object 1000000276
# [info] -- confirmed all values for object 1000000277
#
#
# [info] -- confirmed all values for object 1000000279
# 105 105105
# 105[info] -- confirmed all values for object 1000000281
#
#
# [info] -- confirmed all values for object 1000000280105 105
# 105[info] -- confirmed all values for object 1000000283
# 105
# [info] -- confirmed all values for object 1000000282
# 105 105105
#  [info] -- confirmed all values for object 1000000284105
#
#
# [info] -- confirmed all values for object 1000000285105 105
# [info] -- confirmed all values for object 1000000286
# 105 105[info] -- confirmed all values for object 1000000287
#
# 105 105[info] -- confirmed all values for object 1000000288
#
# 105 105
# [info] -- confirmed all values for object 1000000289
# 105 105
# 105[info] -- confirmed all values for object 1000000291
# 105
# [info] -- confirmed all values for object 1000000293
# 105 105
# [info] -- confirmed all values for object 1000000295
# 105 105
# [info] -- confirmed all values for object 1000000296
# 105 105
# [info] -- confirmed all values for object 1000000297
# 105 105
# [info] -- confirmed all values for object 1000000298
# 105 105
# [info] -- confirmed all values for object 1000000299
# 105 105
# [info] -- confirmed all values for object 1000000301
# 105 105
# [info] -- confirmed all values for object 1000000302105
#
# 105[info] -- confirmed all values for object 1000000305
# 105 105
# [info] -- confirmed all values for object 1000000306
# 105 105
# [info] -- confirmed all values for object 1000000307
# 105 105
# [info] -- confirmed all values for object 1000000310105
#  105
# [info] -- confirmed all values for object 1000000308
# 105 105
# [info] -- confirmed all values for object 1000000311
# 105 105
# [info] -- confirmed all values for object 1000000315
# 105 105
# [info] -- confirmed all values for object 1000000314
# 105 105
# 105[info] -- confirmed all values for object 1000000316
# 105
# [info] -- confirmed all values for object 1000000317
# 105 105
# [info] -- confirmed all values for object 1000000318105
# 105
# [info] -- confirmed all values for object 1000000319
# 105 105
# [info] -- confirmed all values for object 1000000320
# 105 105
# [info] -- confirmed all values for object 1000000323
# 105 105
# [info] -- confirmed all values for object 1000000321
# 105 105
#
# [info] -- confirmed all values for object 1000000324105 105
# [info] -- confirmed all values for object 1000000325
# 105 105
# [info] -- confirmed all values for object 1000000326
# 105 105
# [info] -- confirmed all values for object 1000000329105
# 105 105105
#
# [info] -- confirmed all values for object 1000000328[info] -- confirmed all values for object 1000000330
#
# 105 105
# [info] -- confirmed all values for object 1000000331
# 105 105
# [info] -- confirmed all values for object 1000000332
# 105 105
# [info] -- confirmed all values for object 1000000334
# 105 105
# [info] -- confirmed all values for object 1000000335
# 105 105
# [info] -- confirmed all values for object 1000000336
# 105 105105
#  [info] -- confirmed all values for object 1000000338105
#
# [info] -- confirmed all values for object 1000000337
# 105 105105 105
#
# [info] -- confirmed all values for object 1000000339[info] -- confirmed all values for object 1000000340
#
# 105 105
# [info] -- confirmed all values for object 1000000341
# 105 105
# 105[info] -- confirmed all values for object 1000000345 105
#
# [info] -- confirmed all values for object 1000000342
# 105
# 105[info] -- confirmed all values for object 1000000343
# 105 105
# [info] -- confirmed all values for object 1000000347
# 105105  105
# 105
# [info] -- confirmed all values for object 1000000350[info] -- confirmed all values for object 1000000348
#
# 105 105105
# 105
# [info] -- confirmed all values for object 1000000351[info] -- confirmed all values for object 1000000349
#
# 105 105
# [info] -- confirmed all values for object 1000000352
#  105105
# [info] -- confirmed all values for object 1000000353
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000357
# 105 105
# [info] -- confirmed all values for object 1000000358
# 105 105
# [info] -- confirmed all values for object 1000000359
# 105 105
# [info] -- confirmed all values for object 1000000361
# 105 105
# [info] -- confirmed all values for object 1000000362105
#  105
# [info] -- confirmed all values for object 1000000363
# 105 105
# [info] -- confirmed all values for object 1000000364
# 105 105
# [info] -- confirmed all values for object 1000000365
# 105 105
# [info] -- confirmed all values for object 1000000366
# 105 105
# [info] -- confirmed all values for object 1000000367
# 105 105
# [info] -- confirmed all values for object 1000000368
# 105 105
# [info] -- confirmed all values for object 1000000369
# 105 105
# [info] -- confirmed all values for object 1000000370
# 105105  105
# 105[info] -- confirmed all values for object 1000000373
#
# [info] -- confirmed all values for object 1000000371105
# 105
# [info] -- confirmed all values for object 1000000372
# 105 105
# [info] -- confirmed all values for object 1000000374
# 105 105
# [info] -- confirmed all values for object 1000000375105
#  105
# [info] -- confirmed all values for object 1000000376
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000378
# 105 105
# [info] -- confirmed all values for object 1000000380
# 105 105
# [info] -- confirmed all values for object 1000000379
# 105 105105
#  [info] -- confirmed all values for object 1000000382105
#
# [info] -- confirmed all values for object 1000000381
# 105 105
# [info] -- confirmed all values for object 1000000383
# 105 105
# [info] -- confirmed all values for object 1000000384
# 105105  105105
#
# 105[info] -- confirmed all values for object 1000000388[info] -- confirmed all values for object 1000000386
#
# 105
# [info] -- confirmed all values for object 1000000387
# 105 105
#
# [info] -- confirmed all values for object 1000000392105 105
# [info] -- confirmed all values for object 1000000393
# 105 105
# [info] -- confirmed all values for object 1000000394
# 105 105
# [info] -- confirmed all values for object 1000000395
# 105 105
# [info] -- confirmed all values for object 1000000396105
#  105
# [info] -- confirmed all values for object 1000000397
# 105 105
# [info] -- confirmed all values for object 1000000399
# 105105  105105
#
# [info] -- confirmed all values for object 1000000400[info] -- confirmed all values for object 1000000402
#
# 105 105
# [info] -- confirmed all values for object 1000000401
# 105 105
# [info] -- confirmed all values for object 1000000403
# 105 105
# [info] -- confirmed all values for object 1000000404
# 105 105
# [info] -- confirmed all values for object 1000000405
# 105 105
# [info] -- confirmed all values for object 1000000407105
# 105105
# 105
# [info] -- confirmed all values for object 1000000408105[info] -- confirmed all values for object 1000000412
#
# 101
# 105 105
# [info] -- confirmed all values for object 1000000413
# 105 105
# [info] -- confirmed all values for object 1000000414
# 105 105
# [info] -- confirmed all values for object 1000000415
# 105 105
# [info] -- confirmed all values for object 1000000416
# 105 105
#
# [info] -- confirmed all values for object 1000000417105 105
# [info] -- confirmed all values for object 1000000418
# 105 105
# 105[info] -- confirmed all values for object 1000000419
# 105
# [info] -- confirmed all values for object 1000000420
# 105 105
# [info] -- confirmed all values for object 1000000423
# 105 105
# [info] -- confirmed all values for object 1000000424105
# 105
# [info] -- confirmed all values for object 1000000425
# 105 105
# [info] -- confirmed all values for object 1000000426
# 105 105105
# 105[info] -- confirmed all values for object 1000000428
#
# [info] -- confirmed all values for object 1000000427
# 105 105
# [info] -- confirmed all values for object 1000000430
# 105 105
# 105[info] -- confirmed all values for object 1000000432
# 105
# [info] -- confirmed all values for object 1000000433
# 105 105
# [info] -- confirmed all values for object 1000000434
# 105105  105105105
# [info] -- confirmed all values for object 1000000435
#
#  105[info] -- confirmed all values for object 1000000436
#
# [info] -- confirmed all values for object 1000000437
# 105 105105
# 105
# [info] -- confirmed all values for object 1000000440
# [info] -- confirmed all values for object 1000000438
# 105 105
# [info] -- confirmed all values for object 1000000439105
# 105
# [info] -- confirmed all values for object 1000000441
# 105 105
# [info] -- confirmed all values for object 1000000443
# 105 105
# [info] -- confirmed all values for object 1000000442
# 105 105
# 105[info] -- confirmed all values for object 1000000445 105
#
# [info] -- confirmed all values for object 1000000444
# 105 105
# [info] -- confirmed all values for object 1000000448105
#  105105
#  [info] -- confirmed all values for object 1000000447105
#
# [info] -- confirmed all values for object 1000000446
# 105 105
# [info] -- confirmed all values for object 1000000449
# 105 105
# [info] -- confirmed all values for object 1000000451
# 105 105
# [info] -- confirmed all values for object 1000000453
# 105 105
# [info] -- confirmed all values for object 1000000454
# 105 105
# [info] -- confirmed all values for object 1000000452
# 105 105
# [info] -- confirmed all values for object 1000000455
# 105 105
# [info] -- confirmed all values for object 1000000456
# 105 105
# [info] -- confirmed all values for object 1000000457
# 105
# 105[info] -- confirmed all values for object 1000000458
# 105 105
# [info] -- confirmed all values for object 1000000459
# 105 105
# [info] -- confirmed all values for object 1000000460
# 105105  105105[info] -- confirmed all values for object 1000000462
#
# [info] -- confirmed all values for object 1000000463
#
# 105 105
# [info] -- confirmed all values for object 1000000464
# 105 105
# [info] -- confirmed all values for object 1000000468
# 105 105105
#  105[info] -- confirmed all values for object 1000000465105
#
# 105[info] -- confirmed all values for object 1000000469
#
# [info] -- confirmed all values for object 1000000466
# 105 105
# [info] -- confirmed all values for object 1000000470
# 105 105
# [info] -- confirmed all values for object 1000000471
# 105105
# [info] -- confirmed all values for object 1000000472
# 105 105105
# [info] -- confirmed all values for object 1000000474105
#
# [info] -- confirmed all values for object 1000000473
# 105
# 105[info] -- confirmed all values for object 1000000475
# 105 105
#
# [info] -- confirmed all values for object 1000000476105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000479
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000000482105
#  105
# [info] -- confirmed all values for object 1000000481
# 105 105
# [info] -- confirmed all values for object 1000000484
# 105 105
# [info] -- confirmed all values for object 1000000485
# 105 105
# [info] -- confirmed all values for object 1000000486
# 105 105
# [info] -- confirmed all values for object 1000000488
# 105 101
# 105105  105
# 105[info] -- confirmed all values for object 1000000489
#
# [info] -- confirmed all values for object 1000000490
# 105 105
# [info] -- confirmed all values for object 1000000491
# 105 105
# [info] -- confirmed all values for object 1000000492
# 105 105105
#  [info] -- confirmed all values for object 1000000495105
#
# [info] -- confirmed all values for object 1000000493
# 105 105
# [info] -- confirmed all values for object 1000000494
# 105 105
# 105[info] -- confirmed all values for object 1000000496
# 105
# [info] -- confirmed all values for object 1000000497
# 105 105
# [info] -- confirmed all values for object 1000000499
# 105 105[info] -- confirmed all values for object 1000000498
# 105
# 105  105105
#
# [info] -- confirmed all values for object 1000000501[info] -- confirmed all values for object 1000000500
#
# 105 105
# [info] -- confirmed all values for object 1000000503
# 105 105
# [info] -- confirmed all values for object 1000000505
# 105 105 105105
#
# [info] -- confirmed all values for object 1000000506[info] -- confirmed all values for object 1000000504
#
# 105 105
# [info] -- confirmed all values for object 1000000508
# 105 105
# [info] -- confirmed all values for object 1000000507
# 105 105
# [info] -- confirmed all values for object 1000000510
# 105 105
# [info] -- confirmed all values for object 1000000511
# 105 105
# [info] -- confirmed all values for object 1000000512
# 105 105
# 105 [info] -- confirmed all values for object 1000000514105
#
# [info] -- confirmed all values for object 1000000515
# 105 105
# [info] -- confirmed all values for object 1000000513
# 105 105
# [info] -- confirmed all values for object 1000000516
# 105 105
# [info] -- confirmed all values for object 1000000518
# 105 105
# [info] -- confirmed all values for object 1000000517
# 105 105
# [info] -- confirmed all values for object 1000000519
# 105 105
# [info] -- confirmed all values for object 1000000521
# 105 105105
#  [info] -- confirmed all values for object 1000000522105
#
# [info] -- confirmed all values for object 1000000520
# 105 105
# [info] -- confirmed all values for object 1000000523
# 105 105
#
# [info] -- confirmed all values for object 1000000524105 105
# [info] -- confirmed all values for object 1000000526
# 105 105
# [info] -- confirmed all values for object 1000000525
# 105
# 105[info] -- confirmed all values for object 1000000528
# 105 105
# [info] -- confirmed all values for object 1000000527
# 105 105105
# 105[info] -- confirmed all values for object 1000000530105
#
#  [info] -- confirmed all values for object 1000000529105
#
# [info] -- confirmed all values for object 1000000531
# 105 105
# [info] -- confirmed all values for object 1000000532
# 105 105
# [info] -- confirmed all values for object 1000000533
# 105 105
# [info] -- confirmed all values for object 1000000534
# 105 105105
# 105
# [info] -- confirmed all values for object 1000000538
# [info] -- confirmed all values for object 1000000535
# 105 105
# [info] -- confirmed all values for object 1000000539
# 105105 105
# 105[info] -- confirmed all values for object 1000000541
# [info] -- confirmed all values for object 1000000540
#
# 105 105
# [info] -- confirmed all values for object 1000000542
# 105
# 105[info] -- confirmed all values for object 1000000543
# 105
# 105[info] -- confirmed all values for object 1000000544
# 105105  105105
#
# [info] -- confirmed all values for object 1000000548[info] -- confirmed all values for object 1000000545
#
# 105 105
#
# [info] -- confirmed all values for object 1000000549105 105
# [info] -- confirmed all values for object 1000000550 105
# 105
# [info] -- confirmed all values for object 1000000552105
#  105
# [info] -- confirmed all values for object 1000000554
# 105 105105
# [info] -- confirmed all values for object 1000000555
# 105105
#  105
# [info] -- confirmed all values for object 1000000557[info] -- confirmed all values for object 1000000556
#
# 105 105
# [info] -- confirmed all values for object 1000000558
# 105105  105105
#
# [info] -- confirmed all values for object 1000000559[info] -- confirmed all values for object 1000000561
#
# 105 105105105
# 105105
#
# [info] -- confirmed all values for object 1000000562[info] -- confirmed all values for object 1000000565[info] -- confirmed all values for object 1000000563
#
#
# 105 105
# [info] -- confirmed all values for object 1000000567
# 105 105
# [info] -- confirmed all values for object 1000000566
# 105 105
# [info] -- confirmed all values for object 1000000568
# 105 105
# [info] -- confirmed all values for object 1000000573
# 105 105
# [info] -- confirmed all values for object 1000000570
# 105 105
# [info] -- confirmed all values for object 1000000572
# 105 105
# [info] -- confirmed all values for object 1000000574
# 105 105
# [info] -- confirmed all values for object 1000000575
# 105 105
# [info] -- confirmed all values for object 1000000576
# 105 105
# [info] -- confirmed all values for object 1000000578105
# 105
# [info] -- confirmed all values for object 1000000579
# 105 105
# [info] -- confirmed all values for object 1000000580
# 105 105
# [info] -- confirmed all values for object 1000000581
# 105 105
# [info] -- confirmed all values for object 1000000582
# 105105  105105
#
# [info] -- confirmed all values for object 1000000584[info] -- confirmed all values for object 1000000583
#
# 105 105
#
# [info] -- confirmed all values for object 1000000585105 105
# [info] -- confirmed all values for object 1000000586
# 105 105
# [info] -- confirmed all values for object 1000000587
# 105 105
# [info] -- confirmed all values for object 1000000589
# 105 105105
#  105105[info] -- confirmed all values for object 1000000590
#
# [info] -- confirmed all values for object 1000000591105[info] -- confirmed all values for object 1000000593
#
#
# 105 105
# 105 [info] -- confirmed all values for object 1000000594105
#
# [info] -- confirmed all values for object 1000000595
# 105 105
# [info] -- confirmed all values for object 1000000596
# 105 105
# [info] -- confirmed all values for object 1000000599
# 105 105105
#  [info] -- confirmed all values for object 1000000600105
#
# [info] -- confirmed all values for object 1000000597105
#  105
# [info] -- confirmed all values for object 1000000601
#
# 105 105[info] -- confirmed all values for object 1000000602
# 105 105
# [info] -- confirmed all values for object 1000000603
# 105 105
# [info] -- confirmed all values for object 1000000604105
# 105
# [info] -- confirmed all values for object 1000000605105
# 105
# [info] -- confirmed all values for object 1000000606
# 105 105[info] -- confirmed all values for object 1000000607
#
# 105 105[info] -- confirmed all values for object 1000000608
#
# 105 101105
#  105
# [info] -- confirmed all values for object 1000000609
# 105 105
# [info] -- confirmed all values for object 1000000612
# 105 105
# 105[info] -- confirmed all values for object 1000000613
# 105
# [info] -- confirmed all values for object 1000000614
# 105 105
# [info] -- confirmed all values for object 1000000615
# 105 105
# [info] -- confirmed all values for object 1000000616
# 105 105
# [info] -- confirmed all values for object 1000000618105
#  105
# [info] -- confirmed all values for object 1000000621
# 105 105
# [info] -- confirmed all values for object 1000000619
# 105 105
#
# [info] -- confirmed all values for object 1000000622105 105105
#  105[info] -- confirmed all values for object 1000000623
#
# [info] -- confirmed all values for object 1000000625
# 105 105
# [info] -- confirmed all values for object 1000000624
# 105 105
# [info] -- confirmed all values for object 1000000626
# 105 105
# [info] -- confirmed all values for object 1000000628
# 105 105
# [info] -- confirmed all values for object 1000000629
# 105 105
# [info] -- confirmed all values for object 1000000630
# 105 105
# [info] -- confirmed all values for object 1000000631
# 105 105
# [info] -- confirmed all values for object 1000000633
# 105 105
# [info] -- confirmed all values for object 1000000635
# 105 105
# [info] -- confirmed all values for object 1000000632
# 105 105105
#  105[info] -- confirmed all values for object 1000000636
#
# [info] -- confirmed all values for object 1000000637
# 105 105
# [info] -- confirmed all values for object 1000000638105
#  105
# 105 [info] -- confirmed all values for object 1000000640105
#
# [info] -- confirmed all values for object 1000000639
# 105 105
# [info] -- confirmed all values for object 1000000642
# 105 105
# [info] -- confirmed all values for object 1000000643
# 105 105
# [info] -- confirmed all values for object 1000000644
# 105 105
# [info] -- confirmed all values for object 1000000645
# 105 105
# [info] -- confirmed all values for object 1000000646
# 105 105
# [info] -- confirmed all values for object 1000000647
# 105105  105
# 105[info] -- confirmed all values for object 1000000648
#
# [info] -- confirmed all values for object 1000000649
# 105 105
#
# [info] -- confirmed all values for object 1000000650105 105
# [info] -- confirmed all values for object 1000000685
# 105 105
# [info] -- confirmed all values for object 1000000687
# 105 105
# [info] -- confirmed all values for object 1000000717
# 105 105
# 105[info] -- confirmed all values for object 1000000751 105105
#
# 105[info] -- confirmed all values for object 1000000785
#
# [info] -- confirmed all values for object 1000000786
# 105 101105
#  105
# [info] -- confirmed all values for object 1000000791105
# 105  101105
#
# [info] -- confirmed all values for object 1000000789
# 105 105
# [info] -- confirmed all values for object 1000000818
# 105 105
# [info] -- confirmed all values for object 1000000910
# 105 105
# [info] -- confirmed all values for object 1000000835
# 105 105
# [info] -- confirmed all values for object 1000000872
# 105 105
# [info] -- confirmed all values for object 1000000980
# 105105 105 105
# [info] -- confirmed all values for object 1000000916
#
# [info] -- confirmed all values for object 1000000987
# 105 105
# [info] -- confirmed all values for object 1000000993
# 105 105
# [info] -- confirmed all values for object 1000001052
# 105 105
# [info] -- confirmed all values for object 1000000994
# 105 105
# [info] -- confirmed all values for object 1000001053
# 105 105
# [info] -- confirmed all values for object 1000001055
# 105 105
# [info] -- confirmed all values for object 1000001115
# 105 105
# [info] -- confirmed all values for object 1000001164
# 105 105
# [info] -- confirmed all values for object 1000001144
# 105 105105
#  101[info] -- confirmed all values for object 1000001175
#
# 105 105
# [info] -- confirmed all values for object 1000001210
# 105 105
# [info] -- confirmed all values for object 1000001211
# 105 105
# [info] -- confirmed all values for object 1000001228
# 105 105
# [info] -- confirmed all values for object 1000001272
# 105 105
# [info] -- confirmed all values for object 1000052804
# 105 105
# 105[info] -- confirmed all values for object 1000052821
#
# 105[info] -- confirmed all values for object 1000052831
# 105 105
# [info] -- confirmed all values for object 1000052832
# 105 105
# [info] -- confirmed all values for object 1000052841
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000052851
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000052957
# 105 101
# 105105  105105
#
# [info] -- confirmed all values for object 1000053029[info] -- confirmed all values for object 1000053031
#
# 105 105
# [info] -- confirmed all values for object 1000053069
# 105 105
# [info] -- confirmed all values for object 1000053050
# 105 105
# [info] -- confirmed all values for object 1000053092
# 105 105
# [info] -- confirmed all values for object 1000053212
# 105 105
# [info] -- confirmed all values for object 1000053182
# 105 105
# [info] -- confirmed all values for object 1000053200
# 105105  105101
#
# [info] -- confirmed all values for object 1000053271
# 105 101
# 105105  101105
#
# [info] -- confirmed all values for object 1000053346
# 105 105
# [info] -- confirmed all values for object 1000053425
# 105 105
# [info] -- confirmed all values for object 1000053426
# 105 105
# [info] -- confirmed all values for object 1000053436
# 105 105
# [info] -- confirmed all values for object 1000053445
# 105 105
# [info] -- confirmed all values for object 1000053472
# 105105  105105
#
# [info] -- confirmed all values for object 1000053519[info] -- confirmed all values for object 1000053509
#
# 105 105
# [info] -- confirmed all values for object 1000053585105
#  105
# [info] -- confirmed all values for object 1000053625
# 105 105
# [info] -- confirmed all values for object 1000053614
# 105 105
# [info] -- confirmed all values for object 1000053645
# 105 105
# [info] -- confirmed all values for object 1000053646
# 105 105 105105
#
# [info] -- confirmed all values for object 1000053684[info] -- confirmed all values for object 1000053660
#
# 105 105
# [info] -- confirmed all values for object 1000053751
# 105 105105
#  [info] -- confirmed all values for object 1000053792105
#
# [info] -- confirmed all values for object 1000053763
# 105 105
# [info] -- confirmed all values for object 1000053804
# 105 105
# [info] -- confirmed all values for object 1000053828
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000053834
# 105 105
# [info] -- confirmed all values for object 1000053862
# 105 105
# [info] -- confirmed all values for object 1000053865
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000053885
# 105101
# 105 105
# [info] -- confirmed all values for object 1000053988
# 105 105
# [info] -- confirmed all values for object 1000054006105
#  101
# 105 105
# [info] -- confirmed all values for object 1000054020
# 105105  105105
#
# [info] -- confirmed all values for object 1000054022
# [info] -- confirmed all values for object 1000054061
# 105 101
# 105105  105105
#
# [info] -- confirmed all values for object 1000054146[info] -- confirmed all values for object 1000054112
#
# 105 105
# [info] -- confirmed all values for object 1000054160105
#  105105
# 105[info] -- confirmed all values for object 1000054148
#
#
# [info] -- confirmed all values for object 1000054153105 105
# [info] -- confirmed all values for object 1000054187
# 105 105
# [info] -- confirmed all values for object 1000054188
# 105 105
# 105[info] -- confirmed all values for object 1000054199
# 105
# [info] -- confirmed all values for object 1000054198
# 105 101
# 105101 105
# 105
# [info] -- confirmed all values for object 1000054363
# 105105  105
# 105105[info] -- confirmed all values for object 1000054661
#
#  [info] -- confirmed all values for object 1000054413
# 105
# [info] -- confirmed all values for object 1000054720
# 105 105
# [info] -- confirmed all values for object 1000054772
# 105 105
# [info] -- confirmed all values for object 1000054785
# 105 105
# [info] -- confirmed all values for object 1000054877
# 105 105
# [info] -- confirmed all values for object 1000054897
# 105 105
# 105[info] -- confirmed all values for object 1000054974
# 101
# 105 105
# [info] -- confirmed all values for object 1000055013
# 105 105
# [info] -- confirmed all values for object 1000054995
#  105105
# [info] -- confirmed all values for object 1000055015
# 105 105
# [info] -- confirmed all values for object 1000055051
# 105 105105
# 101[info] -- confirmed all values for object 1000055123
#
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000055104
# 105 101
# 105 101
# 105105105105
#
# [info] -- confirmed all values for object 1000055325[info] -- confirmed all values for object 1000055294
#
# 105 105
# [info] -- confirmed all values for object 1000055326
# 105 105105
#  [info] -- confirmed all values for object 1000055370105
# 105
#  105[info] -- confirmed all values for object 1000055358
#
# [info] -- confirmed all values for object 1000055436
# 105 105
# [info] -- confirmed all values for object 1000055496
# 105105  105105
#
# [info] -- confirmed all values for object 1000055532[info] -- confirmed all values for object 1000055500
#
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000055730
# 105 105
# [info] -- confirmed all values for object 1000055831
# 105 105
# [info] -- confirmed all values for object 1000055840
# 105 105
# [info] -- confirmed all values for object 1000055887
# 105
# 105[info] -- confirmed all values for object 1000055921
# 105105  105101
#
#
# [info] -- confirmed all values for object 1000055943105101
# 105 105105
# 101[info] -- confirmed all values for object 1000055945
#
# 105 105
# [info] -- confirmed all values for object 1000055975
# 105 105
# [info] -- confirmed all values for object 1000056010
# 105 105
# [info] -- confirmed all values for object 1000056040
# 105 101
# 105 101
# 105
# 105105 105[info] -- confirmed all values for object 1000056095
#
# [info] -- confirmed all values for object 1000056116
# 105 101
# 105 105105
# 105[info] -- confirmed all values for object 1000056128
#
# [info] -- confirmed all values for object 1000056256105
#  105
# [info] -- confirmed all values for object 1000056165
# 105105  105101
# [info] -- confirmed all values for object 1000056433
#
# 105 105
# [info] -- confirmed all values for object 1000056497
# 105 105
# [info] -- confirmed all values for object 1000056445
# 105 105
# [info] -- confirmed all values for object 1000056582
# 105 105
# [info] -- confirmed all values for object 1000056631
# 105 105
# [info] -- confirmed all values for object 1000056608
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000056740
# 105 105
# [info] -- confirmed all values for object 1000056800105
# 101
# 105 105
# [info] -- confirmed all values for object 1000056823
# 105 105
# [info] -- confirmed all values for object 1000056893
# 105 105
# [info] -- confirmed all values for object 1000056899
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000056929
# 105 105
# [info] -- confirmed all values for object 1000057017105
#  101
# 105 105
# [info] -- confirmed all values for object 1000057048
# 105 105
# 105[info] -- confirmed all values for object 1000057081
# 105
# [info] -- confirmed all values for object 1000057193
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000057248
# 105 105
# [info] -- confirmed all values for object 1000057275
# 105 105
# [info] -- confirmed all values for object 1000057339
# 105 105
# [info] -- confirmed all values for object 1000057287
# 105105
# [info] -- confirmed all values for object 1000057351
# 105 105
# 105105  105105[info] -- confirmed all values for object 1000057364
# [info] -- confirmed all values for object 1000057428
#
#
# [info] -- confirmed all values for object 1000057372
# 105 105 105105
#
# [info] -- confirmed all values for object 1000057439[info] -- confirmed all values for object 1000057521
#
# 105 105
# [info] -- confirmed all values for object 1000057543
# 105105  105101
#
# [info] -- confirmed all values for object 1000057549
# 105 105
# [info] -- confirmed all values for object 1000057753
# 105 105
# [info] -- confirmed all values for object 1000057783
# 105 105
# [info] -- confirmed all values for object 1000057789
# 105 105
# [info] -- confirmed all values for object 1000057794
# 105 105105
#  101[info] -- confirmed all values for object 1000057867
#
# 105 105
# [info] -- confirmed all values for object 1000057870
# 105105  105105
#
# [info] -- confirmed all values for object 1000057873
# [info] -- confirmed all values for object 1000058052
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000058268
# 105 101
# 105101
# 105 105
# [info] -- confirmed all values for object 1000058345
# 105 105
# 105[info] -- confirmed all values for object 1000058364
# 105
# [info] -- confirmed all values for object 1000058367
# 105101
# 105105  105105
#
# [info] -- confirmed all values for object 1000058624[info] -- confirmed all values for object 1000058695
#
# 105 105
# [info] -- confirmed all values for object 1000058683
# 105 105
# [info] -- confirmed all values for object 1000058748
# 105 105
# 105[info] -- confirmed all values for object 1000058843 105
#
# [info] -- confirmed all values for object 1000058912
# 105 105
# [info] -- confirmed all values for object 1000058931
# 105 105
# [info] -- confirmed all values for object 1000058934
# 105 105
# [info] -- confirmed all values for object 1000058997
# 105 105
# [info] -- confirmed all values for object 1000059053
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000059118
# 105 105
# [info] -- confirmed all values for object 1000059206
# 105 105
# [info] -- confirmed all values for object 1000059217
# 105
# 105105[info] -- confirmed all values for object 1000059479
# 105
# [info] -- confirmed all values for object 1000059285
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000059584
# 105 105
# [info] -- confirmed all values for object 1000059574
# 105 105
# [info] -- confirmed all values for object 1000059637
# 105 105
# [info] -- confirmed all values for object 1000059668
# 105105  105
# 105[info] -- confirmed all values for object 1000059654
#
# [info] -- confirmed all values for object 1000059808
# 105 105
# [info] -- confirmed all values for object 1000059881
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000059948
# 105 105105
# [info] -- confirmed all values for object 1000060063101
# 105
#  101
# 105 105
# [info] -- confirmed all values for object 1000060208
# 105 105105
#  [info] -- confirmed all values for object 1000060219105
#
# [info] -- confirmed all values for object 1000060272
# 105 105
# [info] -- confirmed all values for object 1000060233
# 105 105
# [info] -- confirmed all values for object 1000060332
# 105 105
# [info] -- confirmed all values for object 1000060412
# 105 105
# [info] -- confirmed all values for object 1000060422
# 105 105
# [info] -- confirmed all values for object 1000060720
# 105
# 105[info] -- confirmed all values for object 1000060733
# 105 105
# [info] -- confirmed all values for object 1000060767
# 105 105
# [info] -- confirmed all values for object 1000060848
# 105 105
# [info] -- confirmed all values for object 1000060917
# 105105 105
# 101[info] -- confirmed all values for object 1000060945
# 105
#  105
# [info] -- confirmed all values for object 1000060999
# 105 105
# [info] -- confirmed all values for object 1000061107
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000061256
# 105 105
# [info] -- confirmed all values for object 1000061261
# 105105  105105105
#
# [info] -- confirmed all values for object 1000061290
#  [info] -- confirmed all values for object 1000061337
# 105
# [info] -- confirmed all values for object 1000061285
# 105 105 105105
# [info] -- confirmed all values for object 1000061427
#
# [info] -- confirmed all values for object 1000061413
# 105 105
# [info] -- confirmed all values for object 1000061492
# 105 105
# [info] -- confirmed all values for object 1000061510
# 105
# 105105[info] -- confirmed all values for object 1000061528
# 105
# [info] -- confirmed all values for object 1000061525
# 105 105
# [info] -- confirmed all values for object 1000061563
# 105 105
# [info] -- confirmed all values for object 1000061597105
#  105
# [info] -- confirmed all values for object 1000061602
# 105 105
# [info] -- confirmed all values for object 1000061695
# 105 105
# [info] -- confirmed all values for object 1000061883
# 105 105
# [info] -- confirmed all values for object 1000061869
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000061897
# 105 105
# [info] -- confirmed all values for object 1000061889
# 105 105
# 105[info] -- confirmed all values for object 1000061925 105
#
# [info] -- confirmed all values for object 1000061993
# 105 105
# [info] -- confirmed all values for object 1000061999
# 105 101
# 105 105105
# 105[info] -- confirmed all values for object 1000062194
#
# [info] -- confirmed all values for object 1000062116
# 105 101
# 105105  101101
#
# 105 105
# [info] -- confirmed all values for object 1000062243
# 105 105
# [info] -- confirmed all values for object 1000062278
# 105 105
# [info] -- confirmed all values for object 1000062297
# 105 105
# [info] -- confirmed all values for object 1000062326
# 105 105
# [info] -- confirmed all values for object 1000062368
# 105 105105
#  105[info] -- confirmed all values for object 1000062333
#
# [info] -- confirmed all values for object 1000062428
# 105 105
# [info] -- confirmed all values for object 1000062433105
#  101
# 105 101
# 105 105105
# 105[info] -- confirmed all values for object 1000062486
#
# [info] -- confirmed all values for object 1000062480
# 105
# 101105 105
# [info] -- confirmed all values for object 1000062580
# 105 105
# [info] -- confirmed all values for object 1000062599
# 105 101
# ...
# 105 105
# [info] -- confirmed all values for object 1000086261
# 105 105
# [info] -- confirmed all values for object 1000086257
# 105105
# [info] -- confirmed all values for object 1000086292
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000086369
# 105 105
# [info] -- confirmed all values for object 1000086373
# 105105 105 105101
#
# 105[info] -- confirmed all values for object 1000086413
#
# [info] -- confirmed all values for object 1000086439
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000086504
# 105 105
# [info] -- confirmed all values for object 1000086563
# 105
#  105[info] -- confirmed all values for object 1000086595
# 105 105
# [info] -- confirmed all values for object 1000086597
# 105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000086847
# 105 105
# [info] -- confirmed all values for object 1000086866
# 105 105
# [info] -- confirmed all values for object 1000086880
# 105 105
# [info] -- confirmed all values for object 1000086883
# 105101
# 105 105
# [info] -- confirmed all values for object 1000086982
# 105 105
# 105[info] -- confirmed all values for object 1000087002
#  105
# [info] -- confirmed all values for object 1000086938
# 105 105105
# 105[info] -- confirmed all values for object 1000087011
#
# [info] -- confirmed all values for object 1000087044
# 105 105
# 105[info] -- confirmed all values for object 1000087244
# 105
# [info] -- confirmed all values for object 1000087441
# 105 105
# [info] -- confirmed all values for object 1000087469
# 105 101105
#  105105
#  [info] -- confirmed all values for object 1000087475105
#
# [info] -- confirmed all values for object 1000087671
# 105105  105
# 105[info] -- confirmed all values for object 1000087863
#
# [info] -- confirmed all values for object 1000087816
# 105 105
# [info] -- confirmed all values for object 1000087939
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000087968
# 105 105
# [info] -- confirmed all values for object 1000087975
# 105
# 105[info] -- confirmed all values for object 1000087988
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000088053
# 105 105
# [info] -- confirmed all values for object 1000088107
# 105 105
# [info] -- confirmed all values for object 1000088127
# 105 105
# [info] -- confirmed all values for object 1000088150
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000088266
# 105 105
# [info] -- confirmed all values for object 1000088351
# 105105  105101
#
# [info] -- confirmed all values for object 1000088437
# 105 105 101105
#
# [info] -- confirmed all values for object 1000088612
# 105 105
# [info] -- confirmed all values for object 1000088614
# 105 105
# [info] -- confirmed all values for object 1000088631
# 105 105101
#  105
# [info] -- confirmed all values for object 1000088682
# 105 105
# [info] -- confirmed all values for object 1000088697
# 105 105
# [info] -- confirmed all values for object 1000088736
# 105105  105105
# [info] -- confirmed all values for object 1000088740
#
# [info] -- confirmed all values for object 1000088780
# 105 105
# [info] -- confirmed all values for object 1000088785
# 105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000088838105
#  105
# [info] -- confirmed all values for object 1000088805
# 105 105
# [info] -- confirmed all values for object 1000088921105
#  105
# [info] -- confirmed all values for object 1000088926
# 105 105
# 105[info] -- confirmed all values for object 1000089016
# 105
# [info] -- confirmed all values for object 1000089054
# 105 101
# 105 105105
#  105[info] -- confirmed all values for object 1000089205105
#
# 101[info] -- confirmed all values for object 1000089244
#
# 105 105
# [info] -- confirmed all values for object 1000089302
# 105 105
# [info] -- confirmed all values for object 1000089335
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000089395
# 105 105
# [info] -- confirmed all values for object 1000089443
# 105 105
# [info] -- confirmed all values for object 1000089548
# 105 105
# [info] -- confirmed all values for object 1000089572
# 105 105
# [info] -- confirmed all values for object 1000089665
# 105 105
# [info] -- confirmed all values for object 1000089774
# 105105  105101
#
# [info] -- confirmed all values for object 1000089786
# 105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000089910
# 105 105
# [info] -- confirmed all values for object 1000089954
# 105 105105
#  [info] -- confirmed all values for object 1000089967
# 105
# [info] -- confirmed all values for object 1000089978
# 105 105
# [info] -- confirmed all values for object 1000090117
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000090131
# 105 105
# [info] -- confirmed all values for object 1000090152
# 105 105
# [info] -- confirmed all values for object 1000090160
# 105 105
# [info] -- confirmed all values for object 1000090278
# 105 105
# [info] -- confirmed all values for object 1000090371
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000090398
# 105105 105 105
#
# [info] -- confirmed all values for object 1000090494[info] -- confirmed all values for object 1000090471
# 105
#  105
# [info] -- confirmed all values for object 1000090535
# 105 105
# [info] -- confirmed all values for object 1000090566
# 105 105
# [info] -- confirmed all values for object 1000090572
# 105 105
# [info] -- confirmed all values for object 1000090584
# 105 105[info] -- confirmed all values for object 1000090598
#
# 105 105
# [info] -- confirmed all values for object 1000090592
# 105 105
# [info] -- confirmed all values for object 1000090634105
#  101
# 105 105
# [info] -- confirmed all values for object 1000090655
# 105 105
# 105[info] -- confirmed all values for object 1000090703
#  105
# [info] -- confirmed all values for object 1000090662
# 105 105
# [info] -- confirmed all values for object 1000090756
# 105105 105
#  [info] -- confirmed all values for object 1000090786105
#
# [info] -- confirmed all values for object 1000090839
# 105 105
# [info] -- confirmed all values for object 1000091001
# 105 105
# [info] -- confirmed all values for object 1000091068
# 105 105
# [info] -- confirmed all values for object 1000091110
# 105 105
# 105[info] -- confirmed all values for object 1000091146 105
#
# [info] -- confirmed all values for object 1000091169
# 105 105
# [info] -- confirmed all values for object 1000091181
# 105 105
# [info] -- confirmed all values for object 1000091199
# 105 [info] -- confirmed all values for object 1000091226105
#
# 105 105
#
# [info] -- confirmed all values for object 1000091250105 105
# 105[info] -- confirmed all values for object 1000091267
# 105
# [info] -- confirmed all values for object 1000091311
# 105 105
# [info] -- confirmed all values for object 1000091324
# 105 105
# [info] -- confirmed all values for object 1000091416
# 105 105
# [info] -- confirmed all values for object 1000091512
# 105 105
# [info] -- confirmed all values for object 1000091576
# 105 105
# 105[info] -- confirmed all values for object 1000091652
# 105
# 105[info] -- confirmed all values for object 1000091606105
# 105
# 105
# [info] -- confirmed all values for object 1000091618[info] -- confirmed all values for object 1000091693
#
# 105 105
# [info] -- confirmed all values for object 1000091719
# 105 105105
#  [info] -- confirmed all values for object 1000091725105
#
# [info] -- confirmed all values for object 1000091724
# 105101
# 105105  105105
#
# [info] -- confirmed all values for object 1000091854[info] -- confirmed all values for object 1000091879
#
# 105 105
# 105[info] -- confirmed all values for object 1000091969
# 105
# [info] -- confirmed all values for object 1000092079
# 105 105 105101
#
# [info] -- confirmed all values for object 1000092268105
# 105
# [info] -- confirmed all values for object 1000092331
# 105 105
# [info] -- confirmed all values for object 1000092459
# 105 101
# 105 105 105
# 105[info] -- confirmed all values for object 1000092468
#
# [info] -- confirmed all values for object 1000092505
# 105 105
# 105[info] -- confirmed all values for object 1000092508
#  101
# 105 105
# [info] -- confirmed all values for object 1000092617
# 105
# 105[info] -- confirmed all values for object 1000092653
# 105 105[info] -- confirmed all values for object 1000092776
#
# 105 105
# [info] -- confirmed all values for object 1000092803
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000092807105
#  105
# [info] -- confirmed all values for object 1000092824
# 105 105
# [info] -- confirmed all values for object 1000092838
# 105 105
# [info] -- confirmed all values for object 1000092871
# 105 105
# [info] -- confirmed all values for object 1000092873
# 105105  105105
#
# [info] -- confirmed all values for object 1000092908[info] -- confirmed all values for object 1000092994
#
# 105 105
# [info] -- confirmed all values for object 1000093007
# 105 105105 105
#
# [info] -- confirmed all values for object 1000093050[info] -- confirmed all values for object 1000093100
#
# 105 105
# [info] -- confirmed all values for object 1000093168
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000093214
# 105 101
# 105 105105
#
# [info] -- confirmed all values for object 1000093556 [info] -- confirmed all values for object 1000093536105
#
# 105 105
#
# [info] -- confirmed all values for object 1000093617105105  105101
#
# [info] -- confirmed all values for object 1000093749
# 105 105
# [info] -- confirmed all values for object 1000093871
# 105 105
# 105[info] -- confirmed all values for object 1000094023
#  105
# 105[info] -- confirmed all values for object 1000094033
# 105
# [info] -- confirmed all values for object 1000093930
# 105 101
# 105 105101
# 105
# [info] -- confirmed all values for object 1000094056
# 105 105
# [info] -- confirmed all values for object 1000094095
# 105 101
# 105 105[info] -- confirmed all values for object 1000094169
#
# 105 105
# [info] -- confirmed all values for object 1000094190
# 105 105
# [info] -- confirmed all values for object 1000094220
# 105 105
# [info] -- confirmed all values for object 1000094286105
#  101
# 105 105
# [info] -- confirmed all values for object 1000094352
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000094427
# 105 105
# [info] -- confirmed all values for object 1000094420
# 105
# 101105 105
# [info] -- confirmed all values for object 1000094626
# 105105 105101  105
#
# 101[info] -- confirmed all values for object 1000094658
#
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000094735
# 105 105
# [info] -- confirmed all values for object 1000094739
# 105105
# [info] -- confirmed all values for object 1000094786
# 105 105
# [info] -- confirmed all values for object 1000094798105
#  105
# [info] -- confirmed all values for object 1000094807
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000094957
# 105 105105
# [info] -- confirmed all values for object 1000095052
# 105
# [info] -- confirmed all values for object 1000094962
# 105 105
# [info] -- confirmed all values for object 1000095123
# 105105  105
# 101
#
# [info] -- confirmed all values for object 1000095257105101
# 105 105
# 105 [info] -- confirmed all values for object 1000095351105
#
# [info] -- confirmed all values for object 1000095476
# 105 105
# [info] -- confirmed all values for object 1000095484
# 105105  105105
#
# [info] -- confirmed all values for object 1000095603[info] -- confirmed all values for object 1000095492
#
# 105 105
# [info] -- confirmed all values for object 1000095610
# 105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000095872
# 105 105
# [info] -- confirmed all values for object 1000095916105
#  101
# 105 105
# [info] -- confirmed all values for object 1000095946
# 105 105
# [info] -- confirmed all values for object 1000096022
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000096082
# 105 105105
# [info] -- confirmed all values for object 1000096111
# 101
# 105 101
# 105 105105 105
#
# [info] -- confirmed all values for object 1000096439[info] -- confirmed all values for object 1000096435
#
# 105 101
# 105 105105
# 105
# [info] -- confirmed all values for object 1000096628[info] -- confirmed all values for object 1000096458
#
# 105 105
# 105[info] -- confirmed all values for object 1000096669
# 105
# [info] -- confirmed all values for object 1000096679
# 105 105
# [info] -- confirmed all values for object 1000096701
# 105 105
# [info] -- confirmed all values for object 1000096711
# 105 105
# [info] -- confirmed all values for object 1000096735
# 105 101
# 105 105
# 105105[info] -- confirmed all values for object 1000096756
#
# [info] -- confirmed all values for object 1000096758
# 105 105
# [info] -- confirmed all values for object 1000096763
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000096827
# 105 101
# 105 101
# 105105  101105
#
# [info] -- confirmed all values for object 1000097086
# 105 105105
#  [info] -- confirmed all values for object 1000097102101
#
# 105 105
# [info] -- confirmed all values for object 1000097168
# 105
# 101105 105
# [info] -- confirmed all values for object 1000097257105
# 105
# [info] -- confirmed all values for object 1000097237
# 105 105
# [info] -- confirmed all values for object 1000097310
# 105 101
# 105
# 105[info] -- confirmed all values for object 1000097342
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000097446
# 105 105
# 105[info] -- confirmed all values for object 1000097668
# 105
# [info] -- confirmed all values for object 1000097661
# 105 105
# [info] -- confirmed all values for object 1000097763
# 105 105
# [info] -- confirmed all values for object 1000097853
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000097883
# 105 101
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000097914
# 105 101
# 105
# 105[info] -- confirmed all values for object 1000097935
# 105 101
# 105 105
# [info] -- confirmed all values for object 1000097966
# 105 101
# 105 101
# 105 101105
#  101
# 105 101
# 105 101
# 105 101
# 105 101
# 105 101
# 105 101105
#  101
# 105 101
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/shehan/anaconda3/envs/corev2/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/tmp/ipykernel_826803/4065008201.py", line 43, in validate
#     assert list(gen_values.keys()) == list(
# AssertionError: gen and raw does not match 1000000023
# """
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# /home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> run_stats_validation(generated_df, raw_stats, stats_dict[0])
#
# /home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a>         executor_objects[idx] = executor.submit(
#      <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a>             validate, gen_stats, raw_obj_stats, stats_dict
#      <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=25'>26</a>         )
#      <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=26'>27</a> for obj in executor_objects:
# ---> <a href='vscode-notebook-cell:/home/shehan/Documents/nih_projects/parsers/parser/test_track_parser.ipynb#X10sZmlsZQ%3D%3D?line=27'>28</a>     obj.result()
#
# File ~/anaconda3/envs/corev2/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/envs/corev2/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# AssertionError: gen and raw does not match 1000000023

# %%
out = parser1.inspect.remote(surface_id=0)
out = ray.get(out)["stats_df"]

# %%
out.to_csv('temp.csv')
