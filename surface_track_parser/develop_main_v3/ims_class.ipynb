# %%
import h5py
import numpy as np
import pandas as pd
import re
import yaml
import os
from collections.abc import MutableMapping
from typing import Dict, List
from exceptions import *
from copy import deepcopy
import collections

# %%
# data_path = (
#     "../../data/multi_surface_track_parser_dev_data/GFP #1 Sec1 Roi2 2x2 1h30min.ims"
# )

# %%
data_path = (
    "../../data/multi_surface_track_parser_dev_data/GFP #1 Sec2 Roi1 2x2 1h30min.ims"
)

# %%
class ImarisDataParser(object):
    def __init__(self, ims_file_path: str) -> None:
        self.data = self.load_ims(ims_file_path)
        self.surface_names = self.get_object_names(search_for="Surface")

    def load_ims(self, ims_file_path: str) -> h5py.File:
        """
        loads a imaris file with .ims extension using h5py

        Args:
            ims_file_path (str): path to .ims file

        Returns:
            h5py.File: returns the data contained within the .ims file
        """
        return h5py.File(ims_file_path, "r+")

    def get_object_names(self, search_for: str) -> List:
        """
        extracts the object names that we are interested in.
        objects are usually surfaces( is this always true?)

        Args:
            full_data_file (h5py.File): full imaris file in h5py File format
            search_for (str): string containing full or partial filename to search for

        Returns:
            list: a list of all the object names that match search_for parameter
        """
        try:
            values = self.data.get("Scene8").get("Content").keys()
            storage = list()
            for item in values:
                if len(re.findall(search_for, item)):
                    storage.append(item)
            return storage
        except AttributeError:
            raise NoSurfaceException

    def get_statistics_names(self, object_name: str) -> Dict:
        """
        for a given object_name, extracts the statistics names and ids into a dict
        ex: statistics name = mean intensity, associated id=404

        Args:
            full_data_file (h5py._hl.files.File): full imaris file in h5py File format
            object_name (str): name of the object to get statistic names from

        Returns:
            dict: a dict where the keys=unique stats ID, value=static name
        """

        # get object specific data
        obj_specific_data = self.data.get("Scene8").get("Content").get(object_name)

        # rearrange data
        statistics_name = np.asarray(obj_specific_data["StatisticsType"])
        statistics_name = pd.DataFrame(statistics_name)

        # extract statistics names
        stats_name = statistics_name["Name"]

        # extract statistics ID names
        stats_type = statistics_name["ID"]

        # combine stats type and stats names
        return dict(zip(stats_type, stats_name))

    def get_stats_values(self, object_name: str) -> pd.DataFrame:
        """
        for a given object_name, extracts the statistics values for all object ids
        within the object

        Args:
            full_data_file (h5py._hl.files.File): full imaris file in h5py File format
            object_name (str): name of the object to get statistic names from

        Returns:
            pd.DataFrame: a pandas data frame that contains information about each object id
            where each object id has a stats id and associated stats value.
        """
        # get the track ids
        obj_specific_stats = self.data.get("Scene8").get("Content")[object_name][
            "StatisticsValue"
        ]
        obj_specific_stats = np.asarray(obj_specific_stats)
        return pd.DataFrame(obj_specific_stats)

    def add_channel_info(self, stats_values: Dict) -> Dict:
        """
        Add in channel information to each redundant variable name
        Assumes there are no nested dictionaries. Example: if theres multiple ImageMean strings then each
        ImageMean in acending id order will be renamed ImageMean_channel_1 etc.

        Return:
            stats_values (Dict): a single dictionary with key = stat id, value = state name
        """
        # get counts
        counts = collections.Counter(list(stats_values.values()))

        # map names to id numbers
        inverse_dict = {k: [] for k in counts.keys()}
        for id, name in stats_values.items():
            inverse_dict[name].append(id)

        # rename each id with the updated string
        updated_stats_values = {}
        for name, data in inverse_dict.items():
            if len(data) == 1:
                updated_stats_values[data.pop()] = name
            elif len(data) > 1:
                data = sorted(data)
                for idx, stat_id in enumerate(data):
                    updated_stats_values[stat_id] = f"{name}_channel_{idx+1}"
            else:
                raise ValueError

        return updated_stats_values

    def get_track_ids(self, object_name: str) -> pd.Series:
        """
        Gets all the track ids for a given surface
        Args:
            full_data_file (h5py.File): _description_
            object_name (str): _description_
        """
        try:
            track_ids = pd.DataFrame(
                np.asarray(
                    self.data.get("Scene8").get("Content")[object_name]["Track0"]
                )
            )
            return track_ids["ID"]
        except KeyError:
            raise NoTrackException

    def flatten(self, input_dict: dict, parent_key="", sep="_") -> Dict:
        """
        flattens a nested dictionary

        Args:
            input_dict (dict): _description_
            parent_key (str, optional): _description_. Defaults to ''.
            sep (str, optional): _description_. Defaults to '_'.

        Returns:
            dict: flattened dictionary
        """

        items = []
        for k, v in input_dict.items():
            new_key = parent_key + sep + k if parent_key else k
            if isinstance(v, MutableMapping):
                items.extend(self.flatten(v, new_key, sep=sep).items())
            else:
                items.append((new_key, v))
        return dict(items)

    def generate_stats_names(self) -> Dict[str, Dict[int, str]]:
        """Uses the surface name information from the imaris data file
        and extracts the numerical statistics id and the string
        statistics names for each Surface

        Returns:
            Dict[str, Dict[int, str]]: key=SurfaceName, value=Statistics Dict[id, name]
        """
        object_stats_dict = {}
        for _, name in enumerate(self.surface_names):
            stats_dict = self.get_statistics_names(object_name=name)
            object_stats_dict[name] = stats_dict

        return object_stats_dict

    def generate_stats_values(self) -> Dict[str, Dict[int, pd.DataFrame]]:
        """Uses the surface name information from the imaris data file
        and extracts the numerical statistics id and the associated
        statistics values for each surface

        Returns:
            Dict[str, Dict[int, pd.DataFrame]]: _description_
        """
        stats_values_dict = {}
        for _, name in enumerate(self.surface_names):
            stats_value_dict = self.get_stats_values(object_name=name)
            stats_values_dict[name] = stats_value_dict

        return stats_values_dict

    def map_name_to_id(self, stats_values: Dict, stats_names: Dict):
        storage = {}
        for name in stats_names:
            mapping_dict = stats_names.get(name)
            dataframe = stats_values[name]
            dataframe["Names"] = dataframe["ID_StatisticsType"].map(mapping_dict)
            storage[name] = dataframe
        return storage

    def get_surface_names(self, surface_name: str):
        arr = self.data.get("Scene8").get("Content").get(surface_name).get("Factor")
        surface_names = []
        for item in arr:
            if len(re.findall(b"Surface", item)):
                surface_names.append(item[-1])
        return surface_names

# %%
parser = ImarisDataParser(data_path)
parser.surface_names
# Out:
# ['MegaSurfaces0',
#  'MegaSurfaces1',
#  'MegaSurfaces2',
#  'MegaSurfaces3',
#  'MegaSurfaces4',
#  'MegaSurfaces5',
#  'MegaSurfaces6',
#  'MegaSurfaces7']

# %%
stats_dict_storage = parser.generate_stats_names()
stats_value_storage = parser.generate_stats_values()
unique_surface_names = {name: parser.get_surface_names(name) for name in parser.surface_names}

# %%
stats_dict_storage["MegaSurfaces0"]
# Out:
# {26071: b'Acceleration',
#  26072: b'Acceleration X',
#  26073: b'Acceleration Y',
#  26074: b'Acceleration Z',
#  24927: b'Area',
#  26075: b'BoundingBoxAA Length X',
#  26076: b'BoundingBoxAA Length Y',
#  26077: b'BoundingBoxAA Length Z',
#  26078: b'BoundingBoxOO Length A',
#  26079: b'BoundingBoxOO Length B',
#  26080: b'BoundingBoxOO Length C',
#  26081: b'Center of Homogeneous Mass X',
#  26082: b'Center of Homogeneous Mass Y',
#  26083: b'Center of Homogeneous Mass Z',
#  26084: b'Center of Image Mass X',
#  26085: b'Center of Image Mass X',
#  26086: b'Center of Image Mass X',
#  26087: b'Center of Image Mass X',
#  26088: b'Center of Image Mass X',
#  26089: b'Center of Image Mass Y',
#  26090: b'Center of Image Mass Y',
#  26091: b'Center of Image Mass Y',
#  26092: b'Center of Image Mass Y',
#  26093: b'Center of Image Mass Y',
#  26094: b'Center of Image Mass Z',
#  26095: b'Center of Image Mass Z',
#  26096: b'Center of Image Mass Z',
#  26097: b'Center of Image Mass Z',
#  26098: b'Center of Image Mass Z',
#  26099: b'Displacement Delta Length',
#  26100: b'Displacement Delta X',
#  26101: b'Displacement Delta Y',
#  26102: b'Displacement Delta Z',
#  26103: b'Displacement Length',
#  26104: b'Displacement X',
#  26105: b'Displacement Y',
#  26106: b'Displacement Z',
#  26107: b'Displacement^2',
#  26108: b'Distance from Origin',
#  26109: b'Distance to Image Border XY',
#  26110: b'Distance to Image Border XYZ',
#  26111: b'Ellipsoid Axis A X',
#  26112: b'Ellipsoid Axis A Y',
#  26113: b'Ellipsoid Axis A Z',
#  26114: b'Ellipsoid Axis B X',
#  26115: b'Ellipsoid Axis B Y',
#  26116: b'Ellipsoid Axis B Z',
#  26117: b'Ellipsoid Axis C X',
#  26118: b'Ellipsoid Axis C Y',
#  26119: b'Ellipsoid Axis C Z',
#  26120: b'Ellipsoid Axis Length A',
#  26121: b'Ellipsoid Axis Length B',
#  26122: b'Ellipsoid Axis Length C',
#  26123: b'Ellipticity (oblate)',
#  26124: b'Ellipticity (prolate)',
#  26125: b'Generation',
#  26126: b'Intensity Center',
#  26127: b'Intensity Center',
#  26128: b'Intensity Center',
#  26129: b'Intensity Center',
#  26130: b'Intensity Center',
#  26131: b'Intensity Max',
#  26132: b'Intensity Max',
#  26133: b'Intensity Max',
#  26134: b'Intensity Max',
#  26135: b'Intensity Max',
#  3: b'Intensity Mean',
#  15457: b'Intensity Mean',
#  15699: b'Intensity Mean',
#  26136: b'Intensity Mean',
#  15700: b'Intensity Mean',
#  26137: b'Intensity Median',
#  26138: b'Intensity Median',
#  26139: b'Intensity Median',
#  26140: b'Intensity Median',
#  26141: b'Intensity Median',
#  26142: b'Intensity Min',
#  26143: b'Intensity Min',
#  26144: b'Intensity Min',
#  26145: b'Intensity Min',
#  26146: b'Intensity Min',
#  26147: b'Intensity StdDev',
#  26148: b'Intensity StdDev',
#  26149: b'Intensity StdDev',
#  26150: b'Intensity StdDev',
#  26151: b'Intensity StdDev',
#  26152: b'Intensity Sum',
#  26153: b'Intensity Sum',
#  26154: b'Intensity Sum',
#  26155: b'Intensity Sum',
#  26156: b'Intensity Sum',
#  26157: b'Intensity Sum of Square',
#  26158: b'Intensity Sum of Square',
#  26159: b'Intensity Sum of Square',
#  26160: b'Intensity Sum of Square',
#  26161: b'Intensity Sum of Square',
#  26162: b'Number of Disconnected Components',
#  24926: b'Number of Disconnected Components per Time Point',
#  24925: b'Number of Surfaces per Time Point',
#  5: b'Number of Tracks',
#  26163: b'Number of Triangles',
#  2: b'Number of Voxels',
#  26164: b'Overlapped Volume Ratio to Surfaces',
#  26165: b'Overlapped Volume Ratio to Surfaces',
#  26166: b'Overlapped Volume Ratio to Surfaces',
#  25035: b'Overlapped Volume Ratio to Surfaces',
#  25294: b'Overlapped Volume Ratio to Surfaces',
#  25553: b'Overlapped Volume Ratio to Surfaces',
#  25812: b'Overlapped Volume Ratio to Surfaces',
#  26167: b'Overlapped Volume to Surfaces',
#  26168: b'Overlapped Volume to Surfaces',
#  26169: b'Overlapped Volume to Surfaces',
#  25036: b'Overlapped Volume to Surfaces',
#  25295: b'Overlapped Volume to Surfaces',
#  25554: b'Overlapped Volume to Surfaces',
#  25813: b'Overlapped Volume to Surfaces',
#  26170: b'Position X',
#  26171: b'Position Y',
#  26172: b'Position Z',
#  26173: b'Shortest Distance to Surfaces',
#  26174: b'Shortest Distance to Surfaces',
#  26175: b'Shortest Distance to Surfaces',
#  25034: b'Shortest Distance to Surfaces',
#  25293: b'Shortest Distance to Surfaces',
#  25552: b'Shortest Distance to Surfaces',
#  25811: b'Shortest Distance to Surfaces',
#  26176: b'Speed',
#  26177: b'Sphericity',
#  26178: b'Time',
#  26179: b'Time Index',
#  26180: b'Time Since Track Start',
#  6: b'Total Number of Disconnected Components',
#  7: b'Total Number of Surfaces',
#  8: b'Total Number of Triangles',
#  9: b'Total Number of Voxels',
#  26181: b'Track Ar1 Mean',
#  26182: b'Track Ar1 X',
#  26183: b'Track Ar1 Y',
#  26184: b'Track Ar1 Z',
#  26185: b'Track Area Mean',
#  26186: b'Track Center of Homogeneous Mass X',
#  26187: b'Track Center of Homogeneous Mass Y',
#  26188: b'Track Center of Homogeneous Mass Z',
#  26189: b'Track Center of Image Mass X',
#  26190: b'Track Center of Image Mass X',
#  26191: b'Track Center of Image Mass X',
#  26192: b'Track Center of Image Mass X',
#  26193: b'Track Center of Image Mass X',
#  26194: b'Track Center of Image Mass Y',
#  26195: b'Track Center of Image Mass Y',
#  26196: b'Track Center of Image Mass Y',
#  26197: b'Track Center of Image Mass Y',
#  26198: b'Track Center of Image Mass Y',
#  26199: b'Track Center of Image Mass Z',
#  26200: b'Track Center of Image Mass Z',
#  26201: b'Track Center of Image Mass Z',
#  26202: b'Track Center of Image Mass Z',
#  26203: b'Track Center of Image Mass Z',
#  26204: b'Track Displacement Length',
#  26205: b'Track Displacement X',
#  26206: b'Track Displacement Y',
#  26207: b'Track Displacement Z',
#  4: b'Track Duration',
#  26208: b'Track Ellipsoid Axis A X Mean',
#  26209: b'Track Ellipsoid Axis A Y Mean',
#  26210: b'Track Ellipsoid Axis A Z Mean',
#  26211: b'Track Ellipsoid Axis B X Mean',
#  26212: b'Track Ellipsoid Axis B Y Mean',
#  26213: b'Track Ellipsoid Axis B Z Mean',
#  26214: b'Track Ellipsoid Axis C X Mean',
#  26215: b'Track Ellipsoid Axis C Y Mean',
#  26216: b'Track Ellipsoid Axis C Z Mean',
#  26217: b'Track Ellipsoid Axis Length A Mean',
#  26218: b'Track Ellipsoid Axis Length B Mean',
#  26219: b'Track Ellipsoid Axis Length C Mean',
#  26220: b'Track Ellipticity Oblate Mean',
#  26221: b'Track Ellipticity Prolate Mean',
#  26222: b'Track Intensity Center Mean',
#  26223: b'Track Intensity Center Mean',
#  26224: b'Track Intensity Center Mean',
#  26225: b'Track Intensity Center Mean',
#  26226: b'Track Intensity Center Mean',
#  26227: b'Track Intensity Max',
#  26228: b'Track Intensity Max',
#  26229: b'Track Intensity Max',
#  26230: b'Track Intensity Max',
#  26231: b'Track Intensity Max',
#  26232: b'Track Intensity Mean',
#  26233: b'Track Intensity Mean',
#  26234: b'Track Intensity Mean',
#  26235: b'Track Intensity Mean',
#  26236: b'Track Intensity Mean',
#  26237: b'Track Intensity Median',
#  26238: b'Track Intensity Median',
#  26239: b'Track Intensity Median',
#  26240: b'Track Intensity Median',
#  26241: b'Track Intensity Median',
#  26242: b'Track Intensity Min',
#  26243: b'Track Intensity Min',
#  26244: b'Track Intensity Min',
#  26245: b'Track Intensity Min',
#  26246: b'Track Intensity Min',
#  26247: b'Track Intensity StdDev',
#  26248: b'Track Intensity StdDev',
#  26249: b'Track Intensity StdDev',
#  26250: b'Track Intensity StdDev',
#  26251: b'Track Intensity StdDev',
#  26252: b'Track Intensity Sum',
#  26253: b'Track Intensity Sum',
#  26254: b'Track Intensity Sum',
#  26255: b'Track Intensity Sum',
#  26256: b'Track Intensity Sum',
#  26257: b'Track Length',
#  26258: b'Track Number Of Generations',
#  26259: b'Track Number of Branches',
#  26260: b'Track Number of Fusions',
#  26261: b'Track Number of Surfaces',
#  26262: b'Track Number of Triangles',
#  26263: b'Track Number of Voxels',
#  26264: b'Track Position X Mean',
#  26265: b'Track Position X Start',
#  26266: b'Track Position Y Mean',
#  26267: b'Track Position Y Start',
#  26268: b'Track Position Z Mean',
#  26269: b'Track Position Z Start',
#  26270: b'Track Shortest Distance to Surfaces Min',
#  26271: b'Track Shortest Distance to Surfaces Min',
#  26272: b'Track Shortest Distance to Surfaces Min',
#  26273: b'Track Shortest Distance to Surfaces Min',
#  26274: b'Track Shortest Distance to Surfaces Min',
#  26275: b'Track Shortest Distance to Surfaces Min',
#  26276: b'Track Shortest Distance to Surfaces Min',
#  26277: b'Track Speed Max',
#  26278: b'Track Speed Mean',
#  26279: b'Track Speed Min',
#  26280: b'Track Speed StdDev',
#  26281: b'Track Speed Variation',
#  26282: b'Track Sphericity Mean',
#  26283: b'Track Straightness',
#  26284: b'Track Volume Mean',
#  26285: b'Velocity Angle X',
#  26286: b'Velocity Angle Y',
#  26287: b'Velocity Angle Z',
#  26288: b'Velocity X',
#  26289: b'Velocity Y',
#  26290: b'Velocity Z',
#  26291: b'Volume'}

# %%
unique_surface_names['MegaSurfaces0']
# Out:
# [b'Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]']

# %%
unique_surface_names['MegaSurfaces1']
# Out:
# [b'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]']

# %%
unique_surface_names['MegaSurfaces2']
# Out:
# [b'Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]']

# %%
unique_surface_names['MegaSurfaces3']
# Out:
# [b'Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  b'Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  b'Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]']

# %%
unique_surface_names['MegaSurfaces3']
# Out:
# [b'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]',
#  b'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]',
#  b'Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]']

# %%
def get_surface_names(data):
    arr = data.get("Scene8").get("Content").get("MegaSurfaces1").get("Factor")
    surface_names = []
    for item in arr:
        if len(re.findall(b"Surface", item)):
            surface_names.append(item[-1])

    return surface_names


surface_names = get_surface_names(data)

# %%
surface_names
# Out:
# [b'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]',
#  b'Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]',
#  b'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-23T16-55-31.963]']

# %%
# %timeit list(names.values()).index(b"Center of Image Mass Y")
# Out:
# 1.7 µs ± 1.68 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
[9].pop()
# Out:
# 9
