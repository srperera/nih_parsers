# %% [markdown]
# * Notes
#     * Filename: launch_parser_mp_surface.ipynb
#     * Multiprocessing performed for each file
#     * Example: For each file all surfaces are executed in parallel
#     * Better for Memory Consumption IF imaris files are large

# %%
import sys

sys.path.append(".")

import os
import gc
import ray
import glob
import time
import numpy as np
from utils import utils
import concurrent.futures
from tqdm.notebook import tqdm

os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"  # disables read filelock

# %% [markdown]
# Get Available Categories

# %%
def generate_available_categories(config_path: str, save_path: str):
    # load config path
    yaml = utils.load_yaml(config_path)

    # type of parser
    parser_type = yaml["parser_type"]

    # extract category func
    extract_categories = utils.get_category_function(parser_type)

    # files to scan
    directories = yaml["data_dir"]

    # valid surface
    valid_surface = int(yaml["valid_surface"][0]) - 1

    for directory in directories:
        # grab all the files in the directory w/ .ims
        filenames = list(glob.glob(os.path.join(directory, "*.ims")))

        for filename in filenames:
            # file path
            file_path = filename

            # get and save the available categories csv file
            extract_categories(file_path, valid_surface, save_path)

            break

        break

    print("[info] Please Edit The Statistics File")

# %%
# RUN GENERATE CATEGORIES
# generate_available_categories("configs/config.yaml", ".")

# %% [markdown]
# Generate Statistics

# %%
import logging

logging.basicConfig(format="%(message)s", level=logging.INFO)


def generate_statistics(config_path: str):
    # initialize ray
    ray.init(
        ignore_reinit_error=True,
    )

    # load config path
    yaml = utils.load_yaml(config_path)

    # type of parser
    parser_type = yaml["parser_type"]

    if parser_type == "track":
        from parsers.track_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    elif parser_type == "surface":
        from parsers.surface_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    elif parser_type == "first":
        from parsers.first_surface_parser import extract_data, process_and_save

        print(f"[info] -- parser mode: {parser_type}")

    else:
        raise ValueError("Invalid Parser Type")

    # files to scan
    directories = yaml["data_dir"]

    # get the stats categories
    stats_categories = utils.read_txt(yaml["stats_category_path"])

    # valid surface
    valid_surfaces = yaml["valid_surface"]

    # iterate, process and save
    # parallel processes all files within 1 directory at at time
    for idx, directory in tqdm(enumerate(directories)):
        print(f"[info] -- processing directory index: {idx+1}/{len(directories)}")
        # save dir
        save_dir = yaml["save_dir"][idx]

        # grab all the files in the directory w/ .ims
        filenames = list(glob.glob(os.path.join(directory, "*.ims")))

        for filename in filenames:
            print(f"\n[info] -- processing file {os.path.basename(filename)}\n")
            # load the imaris file
            data = utils.load_ims(filename)

            # create a list to hold ray subprocess
            processes = []
            for surface in valid_surfaces:
                # create folder
                folder_path = os.path.join(save_dir, str(surface))
                if not os.path.isdir(folder_path):
                    os.makedirs(folder_path)

                # convert to zero indexed surface value
                current_surface = int(surface) - 1

                # save_file_path
                save_path = utils.get_save_filepath(
                    parser_type, folder_path, filename, (current_surface + 1)
                )

                # extract data
                extracted_data = extract_data(
                    filename, data, current_surface, save_path
                )

                # process and save
                if extracted_data:
                    # append stats categories to extracted data
                    extracted_data.update({"categories_list": stats_categories})
                    task_ref = process_and_save.remote(extracted_data)
                    processes.append(task_ref)

                else:
                    # there is no surface deleting folder
                    if not os.listdir(folder_path):
                        os.rmdir(folder_path)

            print("\n\t[info] -- finished data extraction")
            print(f"\t[info] -- found {len(processes)} surfaces")
            print(f"\t[info] -- processing {len(processes)} surfaces\n")

            ray.wait(processes, num_returns=len(processes))

            # memory clean up
            del data
            del processes
            gc.collect()

    print(f"\n[info] -- DONE")

# %%
# RUN GENERATE STATISTICS
start = time.perf_counter()
generate_statistics(config_path="configs/config.yaml")
stop = time.perf_counter()
print(f"Total Run Time: {stop - start}")
# Out:
# 2023-08-18 01:01:21,482	INFO worker.py:1621 -- Started a local Ray instance.
# [info] -- parser mode: surface
# 0it [00:00, ?it/s]
# [info] -- processing directory index: 1/1
#
# [info] -- processing file ALN Sec2 Roi1 2x2 1h20min.ims
#
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 0
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 1
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 2
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 3
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 4
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- surface 4 not found
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 5
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- surface 5 not found
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 7
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- surface 7 not found
# 	[info] extracting data: ALN Sec2 Roi1 2x2 1h20min.ims -- surface: 9
# 		[info] -- raised index error
# 		[info] -- skipping file ALN Sec2 Roi1 2x2 1h20min.ims -- surface 9 not found
#
# 	[info] -- finished data extraction
# 	[info] -- found 4 surfaces
# 	[info] -- processing 4 surfaces
#
# (process_and_save pid=74833) 	[info] working on file: ALN Sec2 Roi1 2x2 1h20min.ims -- surface 0
# (process_and_save pid=74834) 	ERROR in FILE: ALN Sec2 Roi1 2x2 1h20min.ims - surface 2 raised Exception ['Value']
# (process_and_save pid=74823) 	[info] working on file: ALN Sec2 Roi1 2x2 1h20min.ims -- surface 3 [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
#
# [info] -- processing file ILN with VLP Tiled 12x18 incomplete.ims
#
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 0
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 1
# (process_and_save pid=74833) 	[info] working on file: ILN with VLP Tiled 12x18 incomplete.ims -- surface 0
# (process_and_save pid=74833) 	ERROR in FILE: ALN Sec2 Roi1 2x2 1h20min.ims - surface 0 raised Exception ['Value'] [repeated 3x across cluster]
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 2
# 	[info] extracting data: ILN with VLP Tiled 12x18 incomplete.ims -- surface: 3
# (raylet) [2023-08-18 01:01:31,480 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696790528; capacity: 1958874054656. Object creation will fail if spilling is required.
# (process_and_save pid=74823) 	ERROR in FILE: ILN with VLP Tiled 12x18 incomplete.ims - surface 2 raised Exception ['Value']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # RUN GENERATE STATISTICS
#       2 start = time.perf_counter()
# ----> 3 generate_statistics(config_path="configs/config.yaml")
#       4 stop = time.perf_counter()
#       5 print(f"Total Run Time: {stop - start}")
#
# Cell In[4], line 77, in generate_statistics(config_path)
#      72 save_path = utils.get_save_filepath(
#      73     parser_type, folder_path, filename, (current_surface + 1)
#      74 )
#      76 # extract data
# ---> 77 extracted_data = extract_data(
#      78     filename, data, current_surface, save_path
#      79 )
#      81 # process and save
#      82 if extracted_data:
#      83     # append stats categories to extracted data
#
# File ~/Documents/nih_projects/parsers/surface_track_parser/main/parsers/surface_parser.py:24, in extract_data(ims_file_path, data, valid_surface, save_path)
#      19 surface_stats_names = utils.get_statistics_names(
#      20     full_data_file=data, object_name=surface_name
#      21 )
#      23 # get the statistics values in the surface
# ---> 24 surface_stats_values = utils.get_stats_values(
#      25     full_data_file=data, object_name=surface_name
#      26 )
#      28 # check for anomalies in the values
#      29 utils.check_anomalies(surface_stats_names, save_path)
#
# File ~/Documents/nih_projects/parsers/surface_track_parser/main/utils/utils.py:128, in get_stats_values(full_data_file, object_name)
#     124 obj_specific_stats = full_data_file.get("Scene8").get("Content")[object_name][
#     125     "StatisticsValue"
#     126 ]
#     127 obj_specific_stats = np.asarray(obj_specific_stats)
# --> 128 return pd.DataFrame(obj_specific_stats)
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/frame.py:674, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     671 if data.dtype.names:
#     672     # i.e. numpy structured array
#     673     data = cast(np.ndarray, data)
# --> 674     mgr = rec_array_to_mgr(
#     675         data,
#     676         index,
#     677         columns,
#     678         dtype,
#     679         copy,
#     680         typ=manager,
#     681     )
#     682 elif getattr(data, "name", None) is not None:
#     683     # i.e. Series/Index with non-None name
#     684     mgr = dict_to_mgr(
#     685         # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686         # attribute "name"
#    (...)
#     691         typ=manager,
#     692     )
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/internals/construction.py:208, in rec_array_to_mgr(data, index, columns, dtype, copy, typ)
#     205 if columns is None:
#     206     columns = arr_columns
# --> 208 mgr = arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ)
#     210 if copy:
#     211     mgr = mgr.copy()
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/internals/construction.py:156, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     153 axes = [columns, index]
#     155 if typ == "block":
# --> 156     return create_block_manager_from_column_arrays(
#     157         arrays, axes, consolidate=consolidate
#     158     )
#     159 elif typ == "array":
#     160     return ArrayManager(arrays, [index, columns])
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1968, in create_block_manager_from_column_arrays(arrays, axes, consolidate)
#    1951 def create_block_manager_from_column_arrays(
#    1952     arrays: list[ArrayLike],
#    1953     axes: list[Index],
#    (...)
#    1964     # These last three are sufficient to allow us to safely pass
#    1965     #  verify_integrity=False below.
#    1967     try:
# -> 1968         blocks = _form_blocks(arrays, consolidate)
#    1969         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    1970     except ValueError as e:
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/internals/managers.py:2042, in _form_blocks(arrays, consolidate)
#    2039 if issubclass(dtype.type, (str, bytes)):
#    2040     dtype = np.dtype(object)
# -> 2042 values, placement = _stack_arrays(list(tup_block), dtype)
#    2043 if is_dtlike:
#    2044     values = ensure_wrapped_if_datetimelike(values)
#
# File ~/anaconda3/envs/corev2/lib/python3.10/site-packages/pandas/core/internals/managers.py:2083, in _stack_arrays(tuples, dtype)
#    2081 stacked = np.empty(shape, dtype=dtype)
#    2082 for i, arr in enumerate(arrays):
# -> 2083     stacked[i] = arr
#    2085 return stacked, placement
#
# KeyboardInterrupt:
# (process_and_save pid=74829) 	ERROR in FILE: ILN with VLP Tiled 12x18 incomplete.ims - surface 1 raised Exception ['Value']
# (raylet) [2023-08-18 01:01:41,493 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696720896; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:01:51,505 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696962560; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:01,516 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696950272; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:11,528 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696950272; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:21,540 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696925696; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:31,552 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696790528; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:41,563 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696745472; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:02:51,576 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696708608; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:01,588 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696659456; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:11,600 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696626688; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:21,612 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696593920; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:31,622 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696593920; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:41,637 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696561152; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:03:51,650 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696532480; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:01,663 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696520192; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:11,675 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696462848; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:21,685 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5680795648; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:31,697 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5696339968; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:41,707 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695705088; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:04:51,715 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695688704; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:01,726 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695643648; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:11,739 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695643648; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:21,752 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695614976; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:31,765 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695553536; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:41,777 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695549440; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:05:51,791 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695549440; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:06:01,802 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695504384; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:06:11,815 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695496192; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:06:21,827 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695447040; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:06:31,839 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 5695397888; capacity: 1958874054656. Object creation will fail if spilling is required.
# (raylet) [2023-08-18 01:06:41,851 E 74732 74745] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-08-18_01-01-19_771660_74587 is over 95% full, available space: 